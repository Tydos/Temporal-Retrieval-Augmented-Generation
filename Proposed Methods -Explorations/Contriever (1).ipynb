# %%
# ============================================================
# CELL 1: Install Dependencies & Imports
# ============================================================
# !pip -q install ir_datasets transformers datasets faiss-cpu pandas pyarrow tqdm

import os, re, json, math, numpy as np, pandas as pd, faiss, torch
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModel

# ==== CONFIGURATION ====
SEED                = 42
DEVICE              = "cuda" if torch.cuda.is_available() else "cpu"

# Index size (subset of full 21M to keep it light)
N_PASSAGES_TOTAL    = 200_000      # tune for your machine
SHARD_ROWS          = 20_000       # rows per shard
BATCH_ENCODE        = 256
MAX_LEN             = 256
USE_COSINE          = False        # if True, L2-normalize vectors; search stays IP

# IVF params
IVF_NLIST           = 32768        # try 16384–65536
IVF_TRAIN_EMB       = 50_000       # vectors to train IVF (<= N_PASSAGES_TOTAL)

# Output paths
OUT_DIR       = "contriever_ivf_wiki_subset"
INDEX_PATH    = os.path.join(OUT_DIR, "ivf.index")
MANIFEST_PATH = os.path.join(OUT_DIR, "manifest.json")
os.makedirs(OUT_DIR, exist_ok=True)

np.random.seed(SEED)
torch.manual_seed(SEED)
print("Device:", DEVICE)
# Out:
# Device: cuda

# %%
# ============================================================
# CELL 2: Load Contriever Model
# ============================================================
CONTRIEVER_MODEL = "facebook/contriever"

print(f"Loading Contriever from {CONTRIEVER_MODEL}...")
tokenizer = AutoTokenizer.from_pretrained(CONTRIEVER_MODEL)
model = AutoModel.from_pretrained(CONTRIEVER_MODEL).to(DEVICE).eval()
print("Contriever loaded successfully!")
print(f"Embedding dimension: {model.config.hidden_size}")
# Out:
# Loading Contriever from facebook/contriever...
# Contriever loaded successfully!
# Embedding dimension: 768

# %%
# ============================================================
# CELL 3: Define Encoding Functions
# ============================================================
def mean_pooling(token_embeddings, attention_mask):
    """
    Contriever uses mean pooling over token embeddings
    """
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

@torch.no_grad()
def encode_contriever(texts, batch=BATCH_ENCODE, max_len=MAX_LEN, normalize=USE_COSINE):
    """
    Encode texts using Contriever encoder with mean pooling
    Works for both queries and passages
    """
    out = []
    for i in range(0, len(texts), batch):
        batch_texts = texts[i:i+batch]

        # Tokenize
        encoded = tokenizer(
            batch_texts,
            padding=True,
            truncation=True,
            max_length=max_len,
            return_tensors="pt"
        ).to(DEVICE)

        # Forward pass
        outputs = model(**encoded)

        # Mean pooling
        embeddings = mean_pooling(outputs.last_hidden_state, encoded['attention_mask'])

        # Optional normalization
        if normalize:
            embeddings = torch.nn.functional.normalize(embeddings, p=2, dim=1)

        out.append(embeddings.float().cpu().numpy())

    return np.vstack(out) if out else np.zeros((0, model.config.hidden_size), dtype=np.float32)

# Wrapper functions for compatibility
def encode_passages_ctx(texts, batch=BATCH_ENCODE, max_len=MAX_LEN, normalize=USE_COSINE):
    """Encode passages - wrapper for consistency"""
    return encode_contriever(texts, batch, max_len, normalize)

def encode_queries(qs, batch=128, max_len=MAX_LEN, normalize=USE_COSINE):
    """Encode queries - wrapper for consistency"""
    return encode_contriever(qs, batch, max_len, normalize)

def write_manifest(chunks, path=MANIFEST_PATH):
    with open(path, "w") as f:
        json.dump(chunks, f)
    return path

def read_manifest(path=MANIFEST_PATH):
    with open(path, "r") as f:
        return json.load(f)

def normalize_text(s):
    s = s.lower()
    s = re.sub(r"[^a-z0-9\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

print("Encoding functions defined successfully!")
# Out:
# Encoding functions defined successfully!

# %%
# ============================================================
# CELL 4: Load DPR-W100 Dataset
# ============================================================
import ir_datasets

print("Loading DPR-W100 dataset...")
dpr = ir_datasets.load("dpr-w100")

def take_docs(dataset, n):
    """Generator over first n docs"""
    i = 0
    for doc in dataset.docs_iter():
        yield doc
        i += 1
        if i >= n:
            break

print("Dataset loaded successfully!")
# Out:
# Loading DPR-W100 dataset...
# Dataset loaded successfully!

# %%
# ============================================================
# CELL 5: Collect & Encode IVF Training Data
# ============================================================
IVF_TRAIN_EMB = min(IVF_TRAIN_EMB, N_PASSAGES_TOTAL)

train_texts = []
for doc in tqdm(take_docs(dpr, IVF_TRAIN_EMB), total=IVF_TRAIN_EMB, desc="Collect IVF train docs"):
    if doc.text:
        train_texts.append(doc.text)

print(f"Encoding {len(train_texts)} training passages...")
train_mat = encode_passages_ctx(train_texts, batch=BATCH_ENCODE)
d = train_mat.shape[1]
print(f"IVF training matrix: {train_mat.shape}, embedding dim: {d}")
# Out:
# [INFO] If you have a local copy of https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/612fe66e0b6b41ee28f806140226c563
# [INFO] [starting] https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz
# Collect IVF train docs:   0%|          | 0/50000 [00:00<?, ?it/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.0%| 0.00/4.69G [00:00<?, ?B/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.0%| 24.6k/4.69G [00:00<6:34:44, 198kB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.0%| 65.5k/4.69G [00:00<5:17:35, 246kB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.0%| 172k/4.69G [00:00<3:05:50, 421kB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.0%| 377k/4.69G [00:00<1:54:20, 684kB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.0%| 795k/4.69G [00:00<1:08:34, 1.14MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.0%| 1.60M/4.69G [00:00<40:52, 1.91MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.1%| 3.23M/4.69G [00:00<23:39, 3.30MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.1%| 6.47M/4.69G [00:01<13:32, 5.77MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.2%| 10.3M/4.69G [00:01<09:39, 8.09MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.3%| 14.3M/4.69G [00:01<07:41, 10.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.4%| 18.4M/4.69G [00:01<06:36, 11.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.5%| 22.5M/4.69G [00:01<05:53, 13.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.6%| 26.5M/4.69G [00:01<05:25, 14.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.7%| 30.6M/4.69G [00:01<05:03, 15.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.7%| 34.7M/4.69G [00:02<04:47, 16.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.8%| 38.8M/4.69G [00:02<04:34, 17.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 0.9%| 42.9M/4.69G [00:02<04:23, 17.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.0%| 46.9M/4.69G [00:02<04:15, 18.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.1%| 51.0M/4.69G [00:02<04:07, 18.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.2%| 55.1M/4.69G [00:02<04:01, 19.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.3%| 59.2M/4.69G [00:03<03:56, 19.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.3%| 63.3M/4.69G [00:03<03:53, 19.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.4%| 67.3M/4.69G [00:03<03:52, 19.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.5%| 71.5M/4.69G [00:03<03:44, 20.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.6%| 75.6M/4.69G [00:03<03:40, 20.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.7%| 79.7M/4.69G [00:03<03:38, 21.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.8%| 83.8M/4.69G [00:03<03:38, 21.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 1.9%| 87.9M/4.69G [00:04<03:36, 21.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.0%| 92.0M/4.69G [00:04<03:34, 21.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.0%| 96.1M/4.69G [00:04<03:35, 21.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.1%| 100M/4.69G [00:04<03:34, 21.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.2%| 104M/4.69G [00:04<03:33, 21.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.3%| 108M/4.69G [00:05<03:33, 21.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.4%| 113M/4.69G [00:05<03:32, 21.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.5%| 117M/4.69G [00:05<03:30, 21.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.6%| 121M/4.69G [00:05<03:31, 21.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.7%| 125M/4.69G [00:05<03:29, 21.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.7%| 129M/4.69G [00:05<03:28, 21.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.8%| 133M/4.69G [00:06<03:25, 22.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 2.9%| 137M/4.69G [00:06<03:22, 22.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 3.0%| 142M/4.69G [00:06<03:20, 22.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 3.1%| 146M/4.69G [00:06<03:16, 23.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 3.2%| 151M/4.69G [00:06<03:14, 23.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 3.3%| 156M/4.69G [00:06<03:12, 23.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 3.5%| 163M/4.69G [00:06<03:07, 24.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 3.6%| 171M/4.69G [00:06<03:05, 24.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 3.8%| 178M/4.69G [00:07<03:03, 24.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 4.0%| 186M/4.69G [00:07<03:02, 24.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 4.1%| 193M/4.69G [00:07<03:01, 24.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 4.3%| 201M/4.69G [00:08<03:00, 24.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 4.4%| 208M/4.69G [00:08<02:59, 24.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 4.6%| 216M/4.69G [00:08<02:59, 25.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 4.8%| 223M/4.69G [00:08<02:56, 25.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 4.9%| 231M/4.69G [00:09<02:56, 25.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 5.1%| 238M/4.69G [00:09<02:56, 25.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 5.2%| 246M/4.69G [00:09<02:55, 25.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 5.4%| 253M/4.69G [00:09<02:54, 25.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 5.6%| 261M/4.69G [00:10<02:54, 25.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 5.7%| 268M/4.69G [00:10<02:53, 25.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 5.9%| 276M/4.69G [00:10<02:53, 25.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 6.0%| 283M/4.69G [00:10<02:51, 25.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 6.2%| 291M/4.69G [00:11<02:50, 25.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 6.4%| 298M/4.69G [00:11<02:51, 25.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 6.5%| 306M/4.69G [00:11<02:49, 25.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 6.7%| 313M/4.69G [00:12<02:49, 25.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 6.8%| 321M/4.69G [00:12<02:49, 25.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 7.0%| 328M/4.69G [00:12<02:48, 25.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 7.2%| 336M/4.69G [00:12<02:48, 25.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 7.3%| 343M/4.69G [00:13<02:46, 26.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 7.5%| 351M/4.69G [00:13<02:46, 26.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 7.6%| 358M/4.69G [00:13<02:45, 26.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 7.8%| 366M/4.69G [00:13<02:45, 26.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 8.0%| 373M/4.69G [00:14<02:45, 26.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 8.1%| 381M/4.69G [00:14<02:44, 26.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 8.3%| 389M/4.69G [00:14<02:44, 26.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 8.4%| 396M/4.69G [00:15<02:43, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 8.6%| 404M/4.69G [00:15<02:42, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 8.8%| 411M/4.69G [00:15<02:42, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 8.9%| 419M/4.69G [00:15<02:42, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 9.1%| 426M/4.69G [00:16<02:41, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 9.2%| 434M/4.69G [00:16<02:41, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 9.4%| 441M/4.69G [00:16<02:41, 26.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 9.6%| 449M/4.69G [00:17<02:41, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 9.7%| 456M/4.69G [00:17<02:41, 26.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 9.9%| 464M/4.69G [00:17<02:40, 26.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 10.0%| 471M/4.69G [00:17<02:39, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 10.2%| 479M/4.69G [00:18<02:38, 26.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 10.4%| 486M/4.69G [00:18<02:38, 26.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 10.5%| 494M/4.69G [00:18<02:38, 26.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 10.7%| 501M/4.69G [00:18<02:38, 26.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 10.8%| 509M/4.69G [00:19<02:38, 26.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 11.0%| 516M/4.69G [00:19<02:37, 26.5MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 11.2%| 524M/4.69G [00:19<02:36, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 11.3%| 531M/4.69G [00:19<02:36, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 11.5%| 539M/4.69G [00:20<02:36, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 11.6%| 546M/4.69G [00:20<02:35, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 11.8%| 554M/4.69G [00:20<02:35, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 12.0%| 561M/4.69G [00:21<02:35, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 12.1%| 569M/4.69G [00:21<02:34, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 12.3%| 576M/4.69G [00:21<02:34, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 12.4%| 584M/4.69G [00:21<02:34, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 12.6%| 591M/4.69G [00:22<02:33, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 12.8%| 599M/4.69G [00:22<02:33, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 12.9%| 606M/4.69G [00:22<02:32, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 13.1%| 614M/4.69G [00:22<02:32, 26.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 13.2%| 621M/4.69G [00:23<02:32, 26.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 13.4%| 629M/4.69G [00:23<02:32, 26.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 13.6%| 636M/4.69G [00:23<02:31, 26.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 13.7%| 644M/4.69G [00:24<02:31, 26.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 13.9%| 651M/4.69G [00:24<02:30, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 14.0%| 659M/4.69G [00:24<02:30, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 14.2%| 666M/4.69G [00:24<02:30, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 14.4%| 674M/4.69G [00:25<02:29, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 14.5%| 681M/4.69G [00:25<02:29, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 14.7%| 689M/4.69G [00:25<02:29, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 14.8%| 697M/4.69G [00:25<02:29, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 15.0%| 704M/4.69G [00:26<02:28, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 15.2%| 712M/4.69G [00:26<02:27, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 15.3%| 719M/4.69G [00:26<02:27, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 15.5%| 727M/4.69G [00:26<02:27, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 15.6%| 734M/4.69G [00:27<02:27, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 15.8%| 742M/4.69G [00:27<02:26, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 16.0%| 749M/4.69G [00:27<02:26, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 16.1%| 757M/4.69G [00:28<02:26, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 16.3%| 764M/4.69G [00:28<02:26, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 16.4%| 772M/4.69G [00:28<02:25, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 16.6%| 779M/4.69G [00:29<02:25, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 16.8%| 787M/4.69G [00:29<02:24, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 16.9%| 794M/4.69G [00:29<02:24, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 17.1%| 802M/4.69G [00:29<02:24, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 17.2%| 809M/4.69G [00:30<02:24, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 17.4%| 817M/4.69G [00:30<02:23, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 17.6%| 824M/4.69G [00:30<02:23, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 17.7%| 832M/4.69G [00:30<02:23, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 17.9%| 839M/4.69G [00:31<02:23, 26.9MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 18.0%| 847M/4.69G [00:31<02:22, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 18.2%| 854M/4.69G [00:31<02:22, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 18.4%| 862M/4.69G [00:31<02:21, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 18.5%| 869M/4.69G [00:32<02:21, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 18.7%| 877M/4.69G [00:32<02:21, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 18.8%| 884M/4.69G [00:32<02:21, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 19.0%| 892M/4.69G [00:33<02:20, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 19.2%| 899M/4.69G [00:33<02:20, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 19.3%| 907M/4.69G [00:33<02:20, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 19.5%| 914M/4.69G [00:33<02:19, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 19.6%| 922M/4.69G [00:34<02:19, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 19.8%| 929M/4.69G [00:34<02:19, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 20.0%| 937M/4.69G [00:34<02:18, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 20.1%| 944M/4.69G [00:34<02:18, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 20.3%| 952M/4.69G [00:35<02:18, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 20.4%| 959M/4.69G [00:35<02:18, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 20.6%| 967M/4.69G [00:35<02:18, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 20.8%| 974M/4.69G [00:35<02:17, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 20.9%| 982M/4.69G [00:36<02:17, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 21.1%| 989M/4.69G [00:36<02:16, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 21.2%| 997M/4.69G [00:36<02:16, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 21.4%| 1.00G/4.69G [00:37<02:16, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 21.6%| 1.01G/4.69G [00:37<02:16, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 21.7%| 1.02G/4.69G [00:37<02:15, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 21.9%| 1.03G/4.69G [00:37<02:15, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 22.0%| 1.03G/4.69G [00:38<02:14, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 22.2%| 1.04G/4.69G [00:38<02:14, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 22.4%| 1.05G/4.69G [00:38<02:14, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 22.5%| 1.06G/4.69G [00:39<02:14, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 22.7%| 1.06G/4.69G [00:39<02:13, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 22.8%| 1.07G/4.69G [00:39<02:13, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 23.0%| 1.08G/4.69G [00:39<02:13, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 23.2%| 1.09G/4.69G [00:40<02:13, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 23.3%| 1.09G/4.69G [00:40<02:12, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 23.5%| 1.10G/4.69G [00:40<02:12, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 23.6%| 1.11G/4.69G [00:40<02:12, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 23.8%| 1.12G/4.69G [00:41<02:11, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 24.0%| 1.12G/4.69G [00:41<02:11, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 24.1%| 1.13G/4.69G [00:41<02:11, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 24.3%| 1.14G/4.69G [00:42<02:11, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 24.4%| 1.15G/4.69G [00:42<02:10, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 24.6%| 1.15G/4.69G [00:42<02:10, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 24.8%| 1.16G/4.69G [00:42<02:09, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 24.9%| 1.17G/4.69G [00:43<02:09, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 25.1%| 1.18G/4.69G [00:43<02:09, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 25.2%| 1.18G/4.69G [00:43<02:09, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 25.4%| 1.19G/4.69G [00:43<02:08, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 25.6%| 1.20G/4.69G [00:44<02:08, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 25.7%| 1.21G/4.69G [00:44<02:08, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 25.9%| 1.21G/4.69G [00:44<02:08, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 26.0%| 1.22G/4.69G [00:45<02:07, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 26.2%| 1.23G/4.69G [00:45<02:07, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 26.4%| 1.24G/4.69G [00:45<02:07, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 26.5%| 1.24G/4.69G [00:45<02:06, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 26.7%| 1.25G/4.69G [00:46<02:06, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 26.8%| 1.26G/4.69G [00:46<02:06, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 27.0%| 1.27G/4.69G [00:46<02:06, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 27.2%| 1.27G/4.69G [00:46<02:05, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 27.3%| 1.28G/4.69G [00:47<02:05, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 27.5%| 1.29G/4.69G [00:47<02:05, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 27.6%| 1.30G/4.69G [00:47<02:04, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 27.8%| 1.30G/4.69G [00:47<02:04, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 28.0%| 1.31G/4.69G [00:48<02:04, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 28.1%| 1.32G/4.69G [00:48<02:04, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 28.3%| 1.33G/4.69G [00:48<02:03, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 28.4%| 1.34G/4.69G [00:49<02:03, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 28.6%| 1.34G/4.69G [00:49<02:03, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 28.8%| 1.35G/4.69G [00:49<02:03, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 28.9%| 1.36G/4.69G [00:49<02:02, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 29.1%| 1.37G/4.69G [00:50<02:02, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 29.2%| 1.37G/4.69G [00:50<02:02, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 29.4%| 1.38G/4.69G [00:50<02:01, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 29.6%| 1.39G/4.69G [00:51<02:01, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 29.7%| 1.40G/4.69G [00:51<02:01, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 29.9%| 1.40G/4.69G [00:51<02:01, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 30.0%| 1.41G/4.69G [00:51<02:00, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 30.2%| 1.42G/4.69G [00:52<02:00, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 30.4%| 1.43G/4.69G [00:52<02:00, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 30.5%| 1.43G/4.69G [00:53<02:02, 26.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 30.7%| 1.44G/4.69G [00:54<02:02, 26.7MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 30.8%| 1.45G/4.69G [00:54<02:02, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 31.0%| 1.46G/4.69G [00:54<02:01, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 31.2%| 1.46G/4.69G [00:55<02:03, 26.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 31.3%| 1.47G/4.69G [00:55<02:02, 26.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 31.6%| 1.48G/4.69G [00:56<02:01, 26.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 31.8%| 1.49G/4.69G [00:56<02:00, 26.6MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 32.1%| 1.51G/4.69G [00:56<01:58, 26.8MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 32.4%| 1.52G/4.69G [00:56<01:57, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 32.6%| 1.53G/4.69G [00:56<01:56, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 32.9%| 1.55G/4.69G [00:56<01:56, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 33.2%| 1.56G/4.69G [00:57<01:55, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 33.5%| 1.57G/4.69G [00:57<01:54, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 33.7%| 1.58G/4.69G [00:58<01:54, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 34.0%| 1.60G/4.69G [00:58<01:54, 27.1MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 34.3%| 1.61G/4.69G [00:59<01:53, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 34.6%| 1.62G/4.69G [00:59<01:53, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 34.8%| 1.63G/4.69G [01:00<01:52, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 35.1%| 1.65G/4.69G [01:00<01:52, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 35.4%| 1.66G/4.69G [01:01<01:51, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 35.6%| 1.67G/4.69G [01:01<01:51, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 35.9%| 1.69G/4.69G [01:02<01:50, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 36.2%| 1.70G/4.69G [01:02<01:50, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 36.5%| 1.71G/4.69G [01:02<01:49, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 36.7%| 1.72G/4.69G [01:03<01:49, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 37.0%| 1.74G/4.69G [01:03<01:48, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 37.3%| 1.75G/4.69G [01:04<01:48, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 37.5%| 1.76G/4.69G [01:04<01:47, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 37.8%| 1.78G/4.69G [01:05<01:47, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 38.1%| 1.79G/4.69G [01:05<01:46, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 38.4%| 1.80G/4.69G [01:06<01:46, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 38.6%| 1.81G/4.69G [01:06<01:45, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 38.9%| 1.83G/4.69G [01:07<01:45, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 39.2%| 1.84G/4.69G [01:07<01:44, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 39.4%| 1.85G/4.69G [01:07<01:44, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 39.7%| 1.86G/4.69G [01:08<01:43, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 40.0%| 1.88G/4.69G [01:08<01:43, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 40.3%| 1.89G/4.69G [01:09<01:42, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 40.5%| 1.90G/4.69G [01:09<01:42, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 40.8%| 1.92G/4.69G [01:10<01:42, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 41.1%| 1.93G/4.69G [01:10<01:41, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 41.4%| 1.94G/4.69G [01:11<01:41, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 41.6%| 1.95G/4.69G [01:11<01:40, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 41.9%| 1.97G/4.69G [01:12<01:40, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 42.2%| 1.98G/4.69G [01:12<01:39, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 42.4%| 1.99G/4.69G [01:13<01:39, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 42.7%| 2.01G/4.69G [01:13<01:38, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 43.0%| 2.02G/4.69G [01:14<01:38, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 43.3%| 2.03G/4.69G [01:14<01:37, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 43.5%| 2.04G/4.69G [01:15<01:37, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 43.8%| 2.06G/4.69G [01:15<01:36, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 44.1%| 2.07G/4.69G [01:15<01:36, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 44.3%| 2.08G/4.69G [01:16<01:35, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 44.6%| 2.09G/4.69G [01:16<01:35, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 44.9%| 2.11G/4.69G [01:17<01:34, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 45.2%| 2.12G/4.69G [01:17<01:34, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 45.4%| 2.13G/4.69G [01:18<01:33, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 45.7%| 2.15G/4.69G [01:18<01:33, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 46.0%| 2.16G/4.69G [01:19<01:32, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 46.3%| 2.17G/4.69G [01:19<01:32, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 46.5%| 2.18G/4.69G [01:20<01:33, 27.0MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 46.9%| 2.20G/4.69G [01:21<01:31, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 47.2%| 2.22G/4.69G [01:21<01:30, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 47.6%| 2.23G/4.69G [01:21<01:30, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 47.9%| 2.25G/4.69G [01:22<01:29, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 48.3%| 2.27G/4.69G [01:23<01:29, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 48.6%| 2.28G/4.69G [01:23<01:28, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 49.0%| 2.30G/4.69G [01:24<01:27, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 49.3%| 2.32G/4.69G [01:24<01:27, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 49.7%| 2.33G/4.69G [01:25<01:26, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 50.0%| 2.35G/4.69G [01:26<01:26, 27.2MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 50.4%| 2.36G/4.69G [01:26<01:25, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 50.7%| 2.38G/4.69G [01:27<01:24, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 51.1%| 2.40G/4.69G [01:27<01:24, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 51.4%| 2.41G/4.69G [01:28<01:23, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 51.8%| 2.43G/4.69G [01:29<01:23, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 52.1%| 2.45G/4.69G [01:29<01:22, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 52.5%| 2.46G/4.69G [01:30<01:21, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 52.8%| 2.48G/4.69G [01:30<01:21, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 53.2%| 2.50G/4.69G [01:31<01:20, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 53.5%| 2.51G/4.69G [01:32<01:20, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 53.9%| 2.53G/4.69G [01:32<01:19, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 54.2%| 2.55G/4.69G [01:33<01:18, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 54.6%| 2.56G/4.69G [01:33<01:18, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 54.9%| 2.58G/4.69G [01:34<01:17, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 55.3%| 2.59G/4.69G [01:35<01:16, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 55.6%| 2.61G/4.69G [01:35<01:16, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 56.0%| 2.63G/4.69G [01:36<01:15, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 56.3%| 2.64G/4.69G [01:36<01:15, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 56.7%| 2.66G/4.69G [01:37<01:14, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 57.0%| 2.68G/4.69G [01:38<01:13, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 57.4%| 2.69G/4.69G [01:38<01:13, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 57.7%| 2.71G/4.69G [01:39<01:12, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 58.1%| 2.73G/4.69G [01:39<01:12, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 58.4%| 2.74G/4.69G [01:40<01:11, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 58.8%| 2.76G/4.69G [01:40<01:10, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 59.1%| 2.78G/4.69G [01:41<01:10, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 59.5%| 2.79G/4.69G [01:42<01:09, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 59.8%| 2.81G/4.69G [01:42<01:08, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 60.2%| 2.82G/4.69G [01:43<01:08, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 60.5%| 2.84G/4.69G [01:43<01:07, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 60.9%| 2.86G/4.69G [01:44<01:07, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 61.2%| 2.87G/4.69G [01:44<01:06, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 61.6%| 2.89G/4.69G [01:45<01:05, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 61.9%| 2.91G/4.69G [01:46<01:05, 27.3MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 62.3%| 2.92G/4.69G [01:46<01:04, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 62.6%| 2.94G/4.69G [01:47<01:04, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 63.0%| 2.96G/4.69G [01:48<01:03, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 63.3%| 2.97G/4.69G [01:48<01:02, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 63.7%| 2.99G/4.69G [01:49<01:02, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 64.0%| 3.00G/4.69G [01:49<01:01, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 64.4%| 3.02G/4.69G [01:50<01:01, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 64.7%| 3.04G/4.69G [01:50<01:00, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 65.1%| 3.05G/4.69G [01:51<00:59, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 65.4%| 3.07G/4.69G [01:52<00:59, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 65.8%| 3.09G/4.69G [01:52<00:58, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 66.1%| 3.10G/4.69G [01:53<00:58, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 66.5%| 3.12G/4.69G [01:53<00:57, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 66.8%| 3.14G/4.69G [01:54<00:56, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 67.2%| 3.15G/4.69G [01:55<00:56, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 67.5%| 3.17G/4.69G [01:55<00:55, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 67.9%| 3.19G/4.69G [01:56<00:55, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 68.2%| 3.20G/4.69G [01:56<00:54, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 68.6%| 3.22G/4.69G [01:57<00:53, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 68.9%| 3.23G/4.69G [01:58<00:53, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 69.3%| 3.25G/4.69G [01:58<00:52, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 69.6%| 3.27G/4.69G [01:59<00:52, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 70.0%| 3.28G/4.69G [01:59<00:51, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 70.3%| 3.30G/4.69G [02:00<00:50, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 70.7%| 3.32G/4.69G [02:01<00:50, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 71.0%| 3.33G/4.69G [02:01<00:49, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 71.4%| 3.35G/4.69G [02:02<00:49, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 71.7%| 3.37G/4.69G [02:02<00:48, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 72.1%| 3.38G/4.69G [02:03<00:47, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 72.4%| 3.40G/4.69G [02:04<00:47, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 72.7%| 3.42G/4.69G [02:04<00:46, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 73.1%| 3.43G/4.69G [02:05<00:46, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 73.4%| 3.45G/4.69G [02:05<00:45, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 73.8%| 3.46G/4.69G [02:06<00:44, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 74.1%| 3.48G/4.69G [02:07<00:44, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 74.5%| 3.50G/4.69G [02:07<00:43, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 74.8%| 3.51G/4.69G [02:08<00:43, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 75.2%| 3.53G/4.69G [02:08<00:42, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 75.5%| 3.55G/4.69G [02:09<00:41, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 75.9%| 3.56G/4.69G [02:10<00:41, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 76.2%| 3.58G/4.69G [02:10<00:40, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 76.6%| 3.60G/4.69G [02:11<00:40, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 76.9%| 3.61G/4.69G [02:11<00:39, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 77.3%| 3.63G/4.69G [02:12<00:38, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 77.6%| 3.65G/4.69G [02:13<00:38, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 78.0%| 3.66G/4.69G [02:13<00:37, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 78.3%| 3.68G/4.69G [02:14<00:37, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 78.7%| 3.69G/4.69G [02:14<00:36, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 79.0%| 3.71G/4.69G [02:15<00:35, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 79.4%| 3.73G/4.69G [02:16<00:35, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 79.7%| 3.74G/4.69G [02:16<00:34, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 80.1%| 3.76G/4.69G [02:17<00:34, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 80.4%| 3.78G/4.69G [02:17<00:33, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 80.8%| 3.79G/4.69G [02:18<00:32, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 81.1%| 3.81G/4.69G [02:19<00:32, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 81.5%| 3.83G/4.69G [02:19<00:31, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 81.8%| 3.84G/4.69G [02:20<00:31, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 82.2%| 3.86G/4.69G [02:20<00:30, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 82.5%| 3.87G/4.69G [02:21<00:29, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 82.9%| 3.89G/4.69G [02:22<00:29, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 83.2%| 3.91G/4.69G [02:22<00:28, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 83.6%| 3.92G/4.69G [02:23<00:28, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 83.9%| 3.94G/4.69G [02:23<00:27, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 84.3%| 3.96G/4.69G [02:24<00:26, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 84.6%| 3.97G/4.69G [02:25<00:26, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 85.0%| 3.99G/4.69G [02:25<00:25, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 85.3%| 4.01G/4.69G [02:26<00:25, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 85.7%| 4.02G/4.69G [02:26<00:24, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 86.0%| 4.04G/4.69G [02:27<00:23, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 86.4%| 4.06G/4.69G [02:27<00:23, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 86.7%| 4.07G/4.69G [02:28<00:22, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 87.1%| 4.09G/4.69G [02:29<00:22, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 87.4%| 4.10G/4.69G [02:29<00:21, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 87.8%| 4.12G/4.69G [02:30<00:20, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 88.1%| 4.14G/4.69G [02:30<00:20, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 88.5%| 4.15G/4.69G [02:31<00:19, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 88.8%| 4.17G/4.69G [02:32<00:19, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 89.2%| 4.19G/4.69G [02:32<00:18, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 89.5%| 4.20G/4.69G [02:33<00:17, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 89.9%| 4.22G/4.69G [02:34<00:17, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 90.2%| 4.24G/4.69G [02:34<00:16, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 90.6%| 4.25G/4.69G [02:35<00:16, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 90.9%| 4.27G/4.69G [02:35<00:15, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 91.3%| 4.29G/4.69G [02:36<00:14, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 91.6%| 4.30G/4.69G [02:36<00:14, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 92.0%| 4.32G/4.69G [02:37<00:13, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 92.3%| 4.33G/4.69G [02:38<00:13, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 92.7%| 4.35G/4.69G [02:38<00:12, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 93.0%| 4.37G/4.69G [02:39<00:11, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 93.4%| 4.38G/4.69G [02:39<00:11, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 93.7%| 4.40G/4.69G [02:40<00:10, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 94.1%| 4.42G/4.69G [02:41<00:10, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 94.4%| 4.43G/4.69G [02:41<00:09, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 94.8%| 4.45G/4.69G [02:42<00:08, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 95.1%| 4.47G/4.69G [02:42<00:08, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 95.5%| 4.48G/4.69G [02:43<00:07, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 95.8%| 4.50G/4.69G [02:44<00:07, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 96.2%| 4.52G/4.69G [02:44<00:06, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 96.5%| 4.53G/4.69G [02:45<00:05, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 96.9%| 4.55G/4.69G [02:45<00:05, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 97.2%| 4.56G/4.69G [02:46<00:04, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 97.6%| 4.58G/4.69G [02:47<00:04, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 97.9%| 4.60G/4.69G [02:47<00:03, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 98.3%| 4.61G/4.69G [02:48<00:02, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 98.6%| 4.63G/4.69G [02:48<00:02, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 99.0%| 4.65G/4.69G [02:49<00:01, 27.4MB/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: 99.3%| 4.66G/4.69G [02:50<00:01, 27.4MB/s]
#
# [INFO] [finished] https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: [02:51] [4.69GB] [27.4MB/s]
# Collect IVF train docs:   0%|          | 0/50000 [02:51<?, ?it/s]
# https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz: [02:51] [4.69GB] [27.4MB/s]
# Collect IVF train docs: 100%|██████████| 50000/50000 [02:52<00:00, 289.98it/s]
# Encoding 50000 training passages...
# IVF training matrix: (50000, 768), embedding dim: 768

# %%
# ============================================================
# CELL 6: Train IVF Index
# ============================================================
print("Building IVF index...")
quantizer = faiss.IndexFlatIP(d)
ivf = faiss.IndexIVFFlat(quantizer, d, IVF_NLIST, faiss.METRIC_INNER_PRODUCT)
ivf.train(train_mat)
print(f"IVF trained: {ivf.is_trained}")
# Out:
# Building IVF index...
# IVF trained: True

# %%
# ============================================================
# CELL 7: Index All Passages & Save Shards
# ============================================================
manifest = []
internal_base = 0
shard_idx = 0

texts, titles = [], []
pbar = tqdm(total=N_PASSAGES_TOTAL, desc="Shard & add to IVF")
count = 0

for doc in dpr.docs_iter():
    if not doc.text:
        continue
    texts.append(doc.text)
    titles.append(doc.title or "")
    count += 1
    pbar.update(1)

    if len(texts) == SHARD_ROWS:
        # Encode and add to index
        emb = encode_passages_ctx(texts, batch=BATCH_ENCODE)
        ivf.add(emb)

        # Save shard
        shard_path = os.path.join(OUT_DIR, f"passages_shard_{shard_idx:05d}.parquet")
        pd.DataFrame({
            "internal_id": np.arange(internal_base, internal_base + len(texts)),
            "title": titles,
            "text": texts
        }).to_parquet(shard_path, index=False)
        manifest.append({"path": shard_path, "start_id": int(internal_base), "n": int(len(texts))})

        internal_base += len(texts)
        shard_idx += 1
        texts, titles = [], []

    if count >= N_PASSAGES_TOTAL:
        break

# Flush remainder
if texts:
    emb = encode_passages_ctx(texts, batch=BATCH_ENCODE)
    ivf.add(emb)
    shard_path = os.path.join(OUT_DIR, f"passages_shard_{shard_idx:05d}.parquet")
    pd.DataFrame({
        "internal_id": np.arange(internal_base, internal_base + len(texts)),
        "title": titles,
        "text": texts
    }).to_parquet(shard_path, index=False)
    manifest.append({"path": shard_path, "start_id": int(internal_base), "n": int(len(texts))})

pbar.close()
print(f"Total vectors added: {ivf.ntotal}")

# Save index and manifest
write_manifest(manifest, MANIFEST_PATH)
faiss.write_index(ivf, INDEX_PATH)
print(f"Saved index to {INDEX_PATH}")
print(f"Saved manifest to {MANIFEST_PATH}")
# Out:
# Shard & add to IVF: 100%|██████████| 200000/200000 [42:09<00:00, 79.06it/s]
# Total vectors added: 200000
# Saved index to contriever_ivf_wiki_subset/ivf.index
# Saved manifest to contriever_ivf_wiki_subset/manifest.json

# %%
# ============================================================
# CELL 8: Load Index for Retrieval
# ============================================================
ivf = faiss.read_index(INDEX_PATH)
with open(MANIFEST_PATH, "r") as f:
    _manifest = json.load(f)

ranges = []
for chunk in _manifest:
    start = int(chunk["start_id"])
    end = start + int(chunk["n"])
    ranges.append((start, end, chunk["path"]))

print(f"Index entries: {ivf.ntotal} | Shards: {len(ranges)}")
# Out:
# Index entries: 200000 | Shards: 10

# %%
# ============================================================
# CELL 9: Define Retrieval Functions
# ============================================================
def load_rows_by_ids(id_list):
    """Return rows in the same order as id_list; None where missing."""
    groups = {}
    for _id in id_list:
        found = False
        for (start, end, path) in ranges:
            if start <= _id < end:
                groups.setdefault(path, []).append(_id)
                found = True
                break
        if not found:
            groups.setdefault(None, []).append(_id)

    fetched = {}
    for path, ids in groups.items():
        if path is None:
            for _id in ids:
                fetched[_id] = None
            continue
        df = pd.read_parquet(path)
        m = df[df["internal_id"].isin(ids)]
        for _, row in m.iterrows():
            fetched[int(row["internal_id"])] = {
                "id": int(row["internal_id"]),
                "title": row["title"],
                "text": row["text"]
            }
        for _id in ids:
            fetched.setdefault(_id, None)

    return [fetched.get(i, None) for i in id_list]

# Tune probing
ivf.nprobe = max(1, min(64, IVF_NLIST // 512))

@torch.no_grad()
def retrieve(question, topk=10):
    """Retrieve top-k passages for a question using Contriever"""
    qv = encode_queries([question]).astype(np.float32)
    D, I = ivf.search(qv, topk)

    # Drop FAISS "no result" ids (-1), keep order
    pairs = [(float(s), int(pid)) for s, pid in zip(D[0], I[0]) if pid != -1]
    if not pairs:
        return []

    ids = [pid for _, pid in pairs]
    rows = load_rows_by_ids(ids)

    hits = []
    for rank, ((score, pid), row) in enumerate(zip(pairs, rows), 1):
        if row is None:
            continue
        hits.append({
            "rank": rank,
            "score": score,
            "internal_id": row["id"],
            "title": row["title"],
            "text": row["text"]
        })
    return hits

print("Retrieval functions defined successfully!")
# Out:
# Retrieval functions defined successfully!

# %%
# ============================================================
# CELL 10: Smoke Test
# ============================================================
test_query = "Who wrote War and Peace?"
print(f"Query: {test_query}\n")
for h in retrieve(test_query, topk=5):
    print(f"{h['rank']:>2}. {h['score']:.3f}  {h['title'][:60]}")
    print(h["text"][:150].replace("\n", " "), "...\n")
# Out:
# Query: Who wrote War and Peace?
#
#  1. 0.978  "Carl von Clausewitz"
# "thought before 1945 other than via British writers, though Generals Eisenhower and Patton were avid readers. He did influence Karl Marx, Friedrich En ...
#
#  2. 0.946  "Carl von Clausewitz"
# "see the sixteen essays presented in ""Clausewitz in the Twenty-First Century"" edited by Hew Strachan and Andreas Herberg-Rothe. In military academie ...
#
#  3. 0.943  "Carl von Clausewitz"
# "his seemingly contradictory claims (discussions pertinent to the tactical, operational and strategic levels of war are one example). Clausewitz const ...
#
#  4. 0.923  "Arthur Schopenhauer"
# "what he has written in ""War and Peace"" is also said by Schopenhauer in ""The World as Will and Representation"". Jorge Luis Borges remarked that th ...
#
#  5. 0.918  "All Quiet on the Western Front"
# "the opening statement that the novel does not advocate any political position, but is merely an attempt to describe the experiences of the soldier. T ...

# %%
# ============================================================
# CELL 11: Load NQ-Open Dataset & Filter by Corpus
# ============================================================
from datasets import load_dataset

def load_nq_open_robust(n=400):
    ds = load_dataset("nq_open")
    split = "validation" if "validation" in ds else ("test" if "test" in ds else "train")
    sub = ds[split].select(range(min(n, ds[split].num_rows)))

    questions, golds = [], []
    for ex in sub:
        q = ex.get("question") or ex.get("query")
        if "answers" in ex:
            a = ex["answers"]
        elif "answer" in ex:
            a = ex["answer"]
        elif "answer_text" in ex:
            a = ex["answer_text"]
        else:
            a = []

        if isinstance(a, str):
            a = [a]
        elif isinstance(a, dict):
            if "text" in a and isinstance(a["text"], (list, tuple)):
                a = list(a["text"])
            elif "value" in a:
                v = a["value"]
                a = v if isinstance(v, (list, tuple)) else [v]
            else:
                vals = []
                for v in a.values():
                    if isinstance(v, (list, tuple)):
                        vals.extend(v)
                    elif isinstance(v, str):
                        vals.append(v)
                a = vals

        if q and a:
            questions.append(q)
            golds.append([str(x) for x in a])

    tag = f"nq_open:{split}[:{len(questions)}]"
    return questions, golds, tag

QUESTIONS, GOLD, TAG = load_nq_open_robust(400)
print(TAG, "| n:", len(QUESTIONS))
for i in range(min(3, len(QUESTIONS))):
    print(f"- Q{i+1}:", QUESTIONS[i])
    print("  gold:", GOLD[i][:3], "...\n")

# Filter questions by corpus coverage
def question_in_corpus(q, golds, retrieve_fn, k=100):
    """Check if any gold answer string appears in retrieved texts."""
    gold_norm = [normalize_text(a) for a in golds]
    H = retrieve_fn(q, topk=k)
    for h in H:
        txt = normalize_text(h["text"])
        if any(g in txt for g in gold_norm):
            return True
    return False

filtered_Q, filtered_G = [], []
for q, g in tqdm(zip(QUESTIONS, GOLD), total=len(QUESTIONS), desc="Filtering by corpus"):
    if question_in_corpus(q, g, retrieve, k=100):
        filtered_Q.append(q)
        filtered_G.append(g)

print(f"Filtered questions: {len(filtered_Q)}/{len(QUESTIONS)} remain in corpus")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# nq_open/train-00000-of-00001.parquet:   0%|          | 0.00/4.46M [00:00<?, ?B/s]
# nq_open/validation-00000-of-00001.parque(…):   0%|          | 0.00/214k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/87925 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3610 [00:00<?, ? examples/s]
# nq_open:validation[:400] | n: 400
# - Q1: when was the last time anyone was on the moon
#   gold: ['14 December 1972 UTC', 'December 1972'] ...
#
# - Q2: who wrote he ain't heavy he's my brother lyrics
#   gold: ['Bobby Scott', 'Bob Russell'] ...
#
# - Q3: how many seasons of the bastard executioner are there
#   gold: ['one', 'one season'] ...
# Filtering by corpus: 100%|██████████| 400/400 [03:55<00:00,  1.70it/s]
# Filtered questions: 171/400 remain in corpus

# %%
# ============================================================
# CELL 12: Evaluate Hit@K Metrics
# ============================================================
def hit_at_k(questions, golds, k=20):
    if not questions:
        return 0.0
    hits = 0
    for q, gold in tqdm(zip(questions, golds), total=len(questions), desc=f"Hit@{k}"):
        gold_norm = [normalize_text(a) for a in gold]
        H = retrieve(q, topk=k)
        found = False
        for h in H:
            txt = normalize_text(h["text"])
            if any(g in txt for g in gold_norm):
                found = True
                break
        hits += int(found)
    return hits / len(questions)

h20 = hit_at_k(filtered_Q, filtered_G, k=20)
h100 = hit_at_k(filtered_Q, filtered_G, k=100)
print(f"\n[{TAG} | filtered] Contriever Retrieval Hit@20={h20:.3f}  Hit@100={h100:.3f}")
# Out:
# Hit@20: 100%|██████████| 171/171 [01:00<00:00,  2.81it/s]
# Hit@100: 100%|██████████| 171/171 [01:38<00:00,  1.73it/s]
# [nq_open:validation[:400] | filtered] Contriever Retrieval Hit@20=0.795  Hit@100=1.000
