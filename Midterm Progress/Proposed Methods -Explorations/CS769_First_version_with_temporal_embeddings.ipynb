# %%
# !pip install transformers datasets torch faiss-cpu tqdm -q

import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from transformers import DPRQuestionEncoder, DPRContextEncoder, DPRQuestionEncoderTokenizer, DPRContextEncoderTokenizer
from datasets import load_dataset
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ------------------------------------------------------------
# 1️⃣ Load and split TimeQA dataset
# ------------------------------------------------------------
raw_dataset = load_dataset("hugosousa/TimeQA", split="train")

# Filter the dataset to keep only the 'hard' questions
hard_dataset = raw_dataset.filter(lambda x: x['level'] == 'hard')

# Use only a 3000 sample subset and create an 80/20 train/test split
# Note: The 'hard' split has about 14,681 samples in the train set, so a 3000 subset is a good choice.
subset_size = 14000
subset = hard_dataset.shuffle(seed=42).select(range(subset_size))

train_test_split = subset.train_test_split(test_size=0.2, seed=42)
train_dataset = train_test_split["train"]
test_dataset = train_test_split["test"]


class TimeQADataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        timestamp = float(item["timestamp"]) if "timestamp" in item and item["timestamp"] else 0.0
        return {
            "question": item["question"],
            "context": item["context"],
            "timestamp": timestamp
        }

train_qa_dataset = TimeQADataset(train_dataset)
test_qa_dataset = TimeQADataset(test_dataset)

# ------------------------------------------------------------
# 2️⃣ Tokenizers
# ------------------------------------------------------------
q_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained("facebook/dpr-question_encoder-single-nq-base")
c_tokenizer = DPRContextEncoderTokenizer.from_pretrained("facebook/dpr-ctx_encoder-single-nq-base")

# ------------------------------------------------------------
# 3️⃣ Collate function
# ------------------------------------------------------------
def collate_fn(batch):
    q_texts = [b["question"] for b in batch]
    c_texts = [b["context"] for b in batch]
    timestamps = torch.tensor([b["timestamp"] for b in batch], dtype=torch.float32)
    return q_texts, c_texts, timestamps

train_loader = DataLoader(train_qa_dataset, batch_size=8, shuffle=True, collate_fn=collate_fn)
test_loader = DataLoader(test_qa_dataset, batch_size=8, shuffle=False, collate_fn=collate_fn)

# ------------------------------------------------------------
# 4️⃣ Global Top-k accuracy
# ------------------------------------------------------------
def compute_global_topk(q_embs, c_embs, k=5):
    scores = torch.matmul(q_embs, c_embs.T)
    topk = scores.topk(k, dim=1).indices
    correct = torch.arange(scores.size(0)).to(scores.device)
    acc = (topk == correct.unsqueeze(1)).any(dim=1).float().mean()
    return acc.item()

# ------------------------------------------------------------
# 5️⃣ Training baseline DPR
# ------------------------------------------------------------
def train_baseline(q_model, c_model, loader, epochs=1):
    q_model.train()
    c_model.train()
    optimizer = optim.Adam(list(q_model.parameters()) + list(c_model.parameters()), lr=2e-5)
    loss_fn = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        for q_texts, c_texts, _ in tqdm(loader, desc=f"Baseline Epoch {epoch+1}"):
            q_inputs = q_tokenizer(
                q_texts, padding=True, truncation=True, max_length=512, return_tensors="pt"
            ).to(device)
            c_inputs = c_tokenizer(
                c_texts, padding=True, truncation=True, max_length=512, return_tensors="pt"
            ).to(device)

            q_emb = q_model(**q_inputs).pooler_output
            c_emb = c_model(**c_inputs).pooler_output

            scores = torch.matmul(q_emb, c_emb.T)
            labels = torch.arange(scores.size(0)).to(device)
            loss = loss_fn(scores, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f"Baseline Epoch {epoch+1} done. Last batch loss: {loss.item():.4f}")

# ------------------------------------------------------------
# 6️⃣ Temporal DPR with learned time embeddings
# ------------------------------------------------------------
class TemporalDPR(nn.Module):
    def __init__(self, q_model, c_model, time_dim=32):
        super().__init__()
        self.q_model = q_model
        self.c_model = c_model
        self.time_embed = nn.Linear(1, time_dim)
        self.proj_q = nn.Linear(q_model.config.hidden_size + time_dim, q_model.config.hidden_size)
        self.proj_c = nn.Linear(c_model.config.hidden_size + time_dim, c_model.config.hidden_size)

    def forward(self, q_inputs, c_inputs, times):
        q_emb = self.q_model(**q_inputs).pooler_output
        c_emb = self.c_model(**c_inputs).pooler_output
        t_emb = self.time_embed(times.unsqueeze(1))
        q_emb = self.proj_q(torch.cat([q_emb, t_emb], dim=-1))
        c_emb = self.proj_c(torch.cat([c_emb, t_emb], dim=-1))
        return q_emb, c_emb

def train_temporal(model, loader, epochs=1):
    model.train()
    optimizer = optim.Adam(model.parameters(), lr=2e-5)
    loss_fn = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        for q_texts, c_texts, times in tqdm(loader, desc=f"Temporal Epoch {epoch+1}"):
            q_inputs = q_tokenizer(
                q_texts, padding=True, truncation=True, max_length=512, return_tensors="pt"
            ).to(device)
            c_inputs = c_tokenizer(
                c_texts, padding=True, truncation=True, max_length=512, return_tensors="pt"
            ).to(device)
            times = times.to(device)

            q_emb, c_emb = model(q_inputs, c_inputs, times)
            scores = torch.matmul(q_emb, c_emb.T)
            labels = torch.arange(scores.size(0)).to(device)
            loss = loss_fn(scores, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f"Temporal Epoch {epoch+1} done. Last batch loss: {loss.item():.4f}")

# ------------------------------------------------------------
# 7️⃣ Evaluation on full dataset
# ------------------------------------------------------------
def evaluate_global(q_model, c_model, loader, temporal_model=None):
    if temporal_model:
        temporal_model.eval()
    else:
        q_model.eval()
        c_model.eval()

    all_q_embs = []
    all_c_embs = []

    with torch.no_grad():
        for q_texts, c_texts, times in tqdm(loader, desc="Embedding all batches"):
            q_inputs = q_tokenizer(
                q_texts, padding=True, truncation=True, max_length=512, return_tensors="pt"
            ).to(device)
            c_inputs = c_tokenizer(
                c_texts, padding=True, truncation=True, max_length=512, return_tensors="pt"
            ).to(device)
            times = times.to(device)

            if temporal_model:
                q_emb, c_emb = temporal_model(q_inputs, c_inputs, times)
            else:
                q_emb = q_model(**q_inputs).pooler_output
                c_emb = c_model(**c_inputs).pooler_output

            all_q_embs.append(q_emb)
            all_c_embs.append(c_emb)

    all_q_embs = torch.cat(all_q_embs, dim=0)
    all_c_embs = torch.cat(all_c_embs, dim=0)
    acc1 = compute_global_topk(all_q_embs, all_c_embs, k=1)
    acc5 = compute_global_topk(all_q_embs, all_c_embs, k=5)
    return acc1, acc5

# ------------------------------------------------------------
# 8️⃣ Instantiate models
# ------------------------------------------------------------
print("\n🧱 Initializing models...")
baseline_q = DPRQuestionEncoder.from_pretrained("facebook/dpr-question_encoder-single-nq-base").to(device)
baseline_c = DPRContextEncoder.from_pretrained("facebook/dpr-ctx_encoder-single-nq-base").to(device)

temp_q = DPRQuestionEncoder.from_pretrained("facebook/dpr-question_encoder-single-nq-base")
temp_c = DPRContextEncoder.from_pretrained("facebook/dpr-ctx_encoder-single-nq-base")
temporal_model = TemporalDPR(temp_q, temp_c).to(device)

# ------------------------------------------------------------
# 9️⃣ Training
# ------------------------------------------------------------
print("\n🧱 Training Baseline DPR...")
train_baseline(baseline_q, baseline_c, train_loader, epochs=3)

print("\n🕰️ Training Temporal DPR...")
train_temporal(temporal_model, train_loader, epochs=6)

# ------------------------------------------------------------
# 🔟 Evaluate
# ------------------------------------------------------------
print("\n📊 Global Evaluation Results on the Test Set:")
baseline_acc1, baseline_acc5 = evaluate_global(baseline_q, baseline_c, test_loader)
print(f"Baseline DPR: Top-1: {baseline_acc1:.3f} | Top-5: {baseline_acc5:.3f}")

temporal_acc1, temporal_acc5 = evaluate_global(None, None, test_loader, temporal_model=temporal_model)
print(f"Temporal DPR: Top-1: {temporal_acc1:.3f} | Top-5: {temporal_acc5:.3f}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 85.0 MB/s eta 0:00:00
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/449 [00:00<?, ?B/s]
# train.json:   0%|          | 0.00/300M [00:00<?, ?B/s]
# dev.json:   0%|          | 0.00/65.5M [00:00<?, ?B/s]
# test.json:   0%|          | 0.00/64.7M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/28989 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/6108 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/6075 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/28989 [00:00<?, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/493 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/492 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizer'.
# 🧱 Initializing models...
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/dpr-question_encoder-single-nq-base were not used when initializing DPRQuestionEncoder: ['question_encoder.bert_model.pooler.dense.bias', 'question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRQuestionEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRQuestionEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/dpr-ctx_encoder-single-nq-base were not used when initializing DPRContextEncoder: ['ctx_encoder.bert_model.pooler.dense.bias', 'ctx_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRContextEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRContextEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at facebook/dpr-question_encoder-single-nq-base were not used when initializing DPRQuestionEncoder: ['question_encoder.bert_model.pooler.dense.bias', 'question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRQuestionEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRQuestionEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/dpr-ctx_encoder-single-nq-base were not used when initializing DPRContextEncoder: ['ctx_encoder.bert_model.pooler.dense.bias', 'ctx_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRContextEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRContextEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 🧱 Training Baseline DPR...
# Baseline Epoch 1:   0%|          | 0/1400 [00:00<?, ?it/s]
# Baseline Epoch 1:   0%|          | 1/1400 [00:01<35:38,  1.53s/it]
# Baseline Epoch 1:   0%|          | 2/1400 [00:01<18:39,  1.25it/s]
# Baseline Epoch 1:   0%|          | 3/1400 [00:02<14:02,  1.66it/s]
# Baseline Epoch 1:   0%|          | 4/1400 [00:02<12:06,  1.92it/s]
# Baseline Epoch 1:   0%|          | 5/1400 [00:02<10:21,  2.24it/s]
# Baseline Epoch 1:   0%|          | 6/1400 [00:03<11:24,  2.04it/s]
# Baseline Epoch 1:   0%|          | 7/1400 [00:03<10:30,  2.21it/s]
# Baseline Epoch 1:   1%|          | 8/1400 [00:04<10:03,  2.31it/s]
# Baseline Epoch 1:   1%|          | 9/1400 [00:04<10:27,  2.22it/s]
# Baseline Epoch 1:   1%|          | 10/1400 [00:05<10:41,  2.17it/s]
# Baseline Epoch 1:   1%|          | 11/1400 [00:05<09:50,  2.35it/s]
# Baseline Epoch 1:   1%|          | 12/1400 [00:05<09:35,  2.41it/s]
# Baseline Epoch 1:   1%|          | 13/1400 [00:06<09:12,  2.51it/s]
# Baseline Epoch 1:   1%|          | 14/1400 [00:06<09:04,  2.54it/s]
# Baseline Epoch 1:   1%|          | 15/1400 [00:07<09:28,  2.44it/s]
# Baseline Epoch 1:   1%|          | 16/1400 [00:07<09:43,  2.37it/s]
# Baseline Epoch 1:   1%|          | 17/1400 [00:07<09:16,  2.49it/s]
# Baseline Epoch 1:   1%|▏         | 18/1400 [00:08<08:40,  2.66it/s]
# Baseline Epoch 1:   1%|▏         | 19/1400 [00:08<09:01,  2.55it/s]
# Baseline Epoch 1:   1%|▏         | 20/1400 [00:09<08:55,  2.58it/s]
# Baseline Epoch 1:   2%|▏         | 21/1400 [00:09<08:58,  2.56it/s]
# Baseline Epoch 1:   2%|▏         | 22/1400 [00:09<09:55,  2.31it/s]
# Baseline Epoch 1:   2%|▏         | 23/1400 [00:10<09:42,  2.36it/s]
# Baseline Epoch 1:   2%|▏         | 24/1400 [00:10<10:09,  2.26it/s]
# Baseline Epoch 1:   2%|▏         | 25/1400 [00:11<09:49,  2.33it/s]
# Baseline Epoch 1:   2%|▏         | 26/1400 [00:11<09:57,  2.30it/s]
# Baseline Epoch 1:   2%|▏         | 27/1400 [00:12<09:46,  2.34it/s]
# Baseline Epoch 1:   2%|▏         | 28/1400 [00:12<09:18,  2.46it/s]
# Baseline Epoch 1:   2%|▏         | 29/1400 [00:12<08:58,  2.55it/s]
# Baseline Epoch 1:   2%|▏         | 30/1400 [00:13<09:44,  2.34it/s]
# Baseline Epoch 1:   2%|▏         | 31/1400 [00:13<10:17,  2.22it/s]
# Baseline Epoch 1:   2%|▏         | 32/1400 [00:14<10:45,  2.12it/s]
# Baseline Epoch 1:   2%|▏         | 33/1400 [00:14<10:54,  2.09it/s]
# Baseline Epoch 1:   2%|▏         | 34/1400 [00:15<10:17,  2.21it/s]
# Baseline Epoch 1:   2%|▎         | 35/1400 [00:15<09:51,  2.31it/s]
# Baseline Epoch 1:   3%|▎         | 36/1400 [00:15<08:57,  2.54it/s]
# Baseline Epoch 1:   3%|▎         | 37/1400 [00:16<09:06,  2.50it/s]
# Baseline Epoch 1:   3%|▎         | 38/1400 [00:16<08:59,  2.52it/s]
# Baseline Epoch 1:   3%|▎         | 39/1400 [00:17<08:36,  2.63it/s]
# Baseline Epoch 1:   3%|▎         | 40/1400 [00:17<08:54,  2.55it/s]
# Baseline Epoch 1:   3%|▎         | 41/1400 [00:18<09:41,  2.34it/s]
# Baseline Epoch 1:   3%|▎         | 42/1400 [00:18<09:22,  2.42it/s]
# Baseline Epoch 1:   3%|▎         | 43/1400 [00:18<08:56,  2.53it/s]
# Baseline Epoch 1:   3%|▎         | 44/1400 [00:19<09:54,  2.28it/s]
# Baseline Epoch 1:   3%|▎         | 45/1400 [00:19<09:07,  2.48it/s]
# Baseline Epoch 1:   3%|▎         | 46/1400 [00:19<08:31,  2.65it/s]
# Baseline Epoch 1:   3%|▎         | 47/1400 [00:20<09:31,  2.37it/s]
# Baseline Epoch 1:   3%|▎         | 48/1400 [00:20<08:54,  2.53it/s]
# Baseline Epoch 1:   4%|▎         | 49/1400 [00:21<08:27,  2.66it/s]
# Baseline Epoch 1:   4%|▎         | 50/1400 [00:21<08:27,  2.66it/s]
# Baseline Epoch 1:   4%|▎         | 51/1400 [00:21<08:23,  2.68it/s]
# Baseline Epoch 1:   4%|▎         | 52/1400 [00:22<08:51,  2.54it/s]
# Baseline Epoch 1:   4%|▍         | 53/1400 [00:22<08:54,  2.52it/s]
# Baseline Epoch 1:   4%|▍         | 54/1400 [00:23<08:36,  2.61it/s]
# Baseline Epoch 1:   4%|▍         | 55/1400 [00:23<08:49,  2.54it/s]
# Baseline Epoch 1:   4%|▍         | 56/1400 [00:23<09:09,  2.45it/s]
# Baseline Epoch 1:   4%|▍         | 57/1400 [00:24<09:45,  2.29it/s]
# Baseline Epoch 1:   4%|▍         | 58/1400 [00:24<10:17,  2.17it/s]
# Baseline Epoch 1:   4%|▍         | 59/1400 [00:25<09:55,  2.25it/s]
# Baseline Epoch 1:   4%|▍         | 60/1400 [00:25<10:19,  2.16it/s]
# Baseline Epoch 1:   4%|▍         | 61/1400 [00:26<10:29,  2.13it/s]
# Baseline Epoch 1:   4%|▍         | 62/1400 [00:26<10:27,  2.13it/s]
# Baseline Epoch 1:   4%|▍         | 63/1400 [00:27<09:57,  2.24it/s]
# Baseline Epoch 1:   5%|▍         | 64/1400 [00:27<09:36,  2.32it/s]
# Baseline Epoch 1:   5%|▍         | 65/1400 [00:28<09:19,  2.39it/s]
# Baseline Epoch 1:   5%|▍         | 66/1400 [00:28<09:01,  2.47it/s]
# Baseline Epoch 1:   5%|▍         | 67/1400 [00:28<09:34,  2.32it/s]
# Baseline Epoch 1:   5%|▍         | 68/1400 [00:29<10:18,  2.15it/s]
# Baseline Epoch 1:   5%|▍         | 69/1400 [00:29<09:45,  2.27it/s]
# Baseline Epoch 1:   5%|▌         | 70/1400 [00:30<09:02,  2.45it/s]
# Baseline Epoch 1:   5%|▌         | 71/1400 [00:30<08:45,  2.53it/s]
# Baseline Epoch 1:   5%|▌         | 72/1400 [00:31<09:57,  2.22it/s]
# Baseline Epoch 1:   5%|▌         | 73/1400 [00:31<09:10,  2.41it/s]
# Baseline Epoch 1:   5%|▌         | 74/1400 [00:31<09:09,  2.41it/s]
# Baseline Epoch 1:   5%|▌         | 75/1400 [00:32<09:19,  2.37it/s]
# Baseline Epoch 1:   5%|▌         | 76/1400 [00:32<09:06,  2.42it/s]
# Baseline Epoch 1:   6%|▌         | 77/1400 [00:33<09:27,  2.33it/s]
# Baseline Epoch 1:   6%|▌         | 78/1400 [00:33<09:25,  2.34it/s]
# Baseline Epoch 1:   6%|▌         | 79/1400 [00:33<09:20,  2.36it/s]
# Baseline Epoch 1:   6%|▌         | 80/1400 [00:34<08:54,  2.47it/s]
# Baseline Epoch 1:   6%|▌         | 81/1400 [00:34<08:34,  2.57it/s]
# Baseline Epoch 1:   6%|▌         | 82/1400 [00:35<08:14,  2.67it/s]
# Baseline Epoch 1:   6%|▌         | 83/1400 [00:35<08:09,  2.69it/s]
# Baseline Epoch 1:   6%|▌         | 84/1400 [00:35<07:46,  2.82it/s]
# Baseline Epoch 1:   6%|▌         | 85/1400 [00:36<07:40,  2.86it/s]
# Baseline Epoch 1:   6%|▌         | 86/1400 [00:36<07:45,  2.82it/s]
# Baseline Epoch 1:   6%|▌         | 87/1400 [00:36<07:47,  2.81it/s]
# Baseline Epoch 1:   6%|▋         | 88/1400 [00:37<09:02,  2.42it/s]
# Baseline Epoch 1:   6%|▋         | 89/1400 [00:37<10:27,  2.09it/s]
# Baseline Epoch 1:   6%|▋         | 90/1400 [00:38<10:00,  2.18it/s]
# Baseline Epoch 1:   6%|▋         | 91/1400 [00:38<09:12,  2.37it/s]
# Baseline Epoch 1:   7%|▋         | 92/1400 [00:39<08:47,  2.48it/s]
# Baseline Epoch 1:   7%|▋         | 93/1400 [00:39<08:34,  2.54it/s]
# Baseline Epoch 1:   7%|▋         | 94/1400 [00:39<08:22,  2.60it/s]
# Baseline Epoch 1:   7%|▋         | 95/1400 [00:40<08:26,  2.58it/s]
# Baseline Epoch 1:   7%|▋         | 96/1400 [00:40<08:29,  2.56it/s]
# Baseline Epoch 1:   7%|▋         | 97/1400 [00:40<08:35,  2.53it/s]
# Baseline Epoch 1:   7%|▋         | 98/1400 [00:41<08:03,  2.69it/s]
# Baseline Epoch 1:   7%|▋         | 99/1400 [00:41<08:11,  2.65it/s]
# Baseline Epoch 1:   7%|▋         | 100/1400 [00:42<07:59,  2.71it/s]
# Baseline Epoch 1:   7%|▋         | 101/1400 [00:42<07:40,  2.82it/s]
# Baseline Epoch 1:   7%|▋         | 102/1400 [00:42<08:41,  2.49it/s]
# Baseline Epoch 1:   7%|▋         | 103/1400 [00:43<08:45,  2.47it/s]
# Baseline Epoch 1:   7%|▋         | 104/1400 [00:43<08:32,  2.53it/s]
# Baseline Epoch 1:   8%|▊         | 105/1400 [00:44<08:54,  2.42it/s]
# Baseline Epoch 1:   8%|▊         | 106/1400 [00:44<08:18,  2.59it/s]
# Baseline Epoch 1:   8%|▊         | 107/1400 [00:44<08:19,  2.59it/s]
# Baseline Epoch 1:   8%|▊         | 108/1400 [00:45<08:46,  2.45it/s]
# Baseline Epoch 1:   8%|▊         | 109/1400 [00:45<08:30,  2.53it/s]
# Baseline Epoch 1:   8%|▊         | 110/1400 [00:46<08:35,  2.50it/s]
# Baseline Epoch 1:   8%|▊         | 111/1400 [00:46<08:17,  2.59it/s]
# Baseline Epoch 1:   8%|▊         | 112/1400 [00:46<08:04,  2.66it/s]
# Baseline Epoch 1:   8%|▊         | 113/1400 [00:47<08:12,  2.62it/s]
# Baseline Epoch 1:   8%|▊         | 114/1400 [00:47<09:32,  2.25it/s]
# Baseline Epoch 1:   8%|▊         | 115/1400 [00:48<08:57,  2.39it/s]
# Baseline Epoch 1:   8%|▊         | 116/1400 [00:48<08:45,  2.44it/s]
# Baseline Epoch 1:   8%|▊         | 117/1400 [00:48<08:26,  2.53it/s]
# Baseline Epoch 1:   8%|▊         | 118/1400 [00:49<09:10,  2.33it/s]
# Baseline Epoch 1:   8%|▊         | 119/1400 [00:49<10:03,  2.12it/s]
# Baseline Epoch 1:   9%|▊         | 120/1400 [00:50<09:25,  2.26it/s]
# Baseline Epoch 1:   9%|▊         | 121/1400 [00:50<09:20,  2.28it/s]
# Baseline Epoch 1:   9%|▊         | 122/1400 [00:51<09:04,  2.35it/s]
# Baseline Epoch 1:   9%|▉         | 123/1400 [00:51<09:54,  2.15it/s]
# Baseline Epoch 1:   9%|▉         | 124/1400 [00:52<10:01,  2.12it/s]
# Baseline Epoch 1:   9%|▉         | 125/1400 [00:52<09:16,  2.29it/s]
# Baseline Epoch 1:   9%|▉         | 126/1400 [00:52<08:35,  2.47it/s]
# Baseline Epoch 1:   9%|▉         | 127/1400 [00:53<09:32,  2.22it/s]
# Baseline Epoch 1:   9%|▉         | 128/1400 [00:53<08:49,  2.40it/s]
# Baseline Epoch 1:   9%|▉         | 129/1400 [00:54<08:38,  2.45it/s]
# Baseline Epoch 1:   9%|▉         | 130/1400 [00:54<09:05,  2.33it/s]
# Baseline Epoch 1:   9%|▉         | 131/1400 [00:55<09:16,  2.28it/s]
# Baseline Epoch 1:   9%|▉         | 132/1400 [00:55<09:22,  2.26it/s]
# Baseline Epoch 1:  10%|▉         | 133/1400 [00:55<09:05,  2.32it/s]
# Baseline Epoch 1:  10%|▉         | 134/1400 [00:56<09:37,  2.19it/s]
# Baseline Epoch 1:  10%|▉         | 135/1400 [00:56<09:24,  2.24it/s]
# Baseline Epoch 1:  10%|▉         | 136/1400 [00:57<08:42,  2.42it/s]
# Baseline Epoch 1:  10%|▉         | 137/1400 [00:57<08:30,  2.47it/s]
# Baseline Epoch 1:  10%|▉         | 138/1400 [00:57<08:08,  2.58it/s]
# Baseline Epoch 1:  10%|▉         | 139/1400 [00:58<08:16,  2.54it/s]
# Baseline Epoch 1:  10%|█         | 140/1400 [00:58<08:14,  2.55it/s]
# Baseline Epoch 1:  10%|█         | 141/1400 [00:59<08:23,  2.50it/s]
# Baseline Epoch 1:  10%|█         | 142/1400 [00:59<08:17,  2.53it/s]
# Baseline Epoch 1:  10%|█         | 143/1400 [00:59<08:04,  2.60it/s]
# Baseline Epoch 1:  10%|█         | 144/1400 [01:00<08:23,  2.50it/s]
# Baseline Epoch 1:  10%|█         | 145/1400 [01:00<07:48,  2.68it/s]
# Baseline Epoch 1:  10%|█         | 146/1400 [01:01<07:47,  2.68it/s]
# Baseline Epoch 1:  10%|█         | 147/1400 [01:01<07:36,  2.74it/s]
# Baseline Epoch 1:  11%|█         | 148/1400 [01:02<09:31,  2.19it/s]
# Baseline Epoch 1:  11%|█         | 149/1400 [01:02<09:15,  2.25it/s]
# Baseline Epoch 1:  11%|█         | 150/1400 [01:02<09:38,  2.16it/s]
# Baseline Epoch 1:  11%|█         | 151/1400 [01:03<09:42,  2.14it/s]
# Baseline Epoch 1:  11%|█         | 152/1400 [01:03<08:57,  2.32it/s]
# Baseline Epoch 1:  11%|█         | 153/1400 [01:04<08:27,  2.46it/s]
# Baseline Epoch 1:  11%|█         | 154/1400 [01:04<08:31,  2.43it/s]
# Baseline Epoch 1:  11%|█         | 155/1400 [01:05<09:29,  2.19it/s]
# Baseline Epoch 1:  11%|█         | 156/1400 [01:05<09:12,  2.25it/s]
# Baseline Epoch 1:  11%|█         | 157/1400 [01:05<08:47,  2.36it/s]
# Baseline Epoch 1:  11%|█▏        | 158/1400 [01:06<08:51,  2.34it/s]
# Baseline Epoch 1:  11%|█▏        | 159/1400 [01:06<09:21,  2.21it/s]
# Baseline Epoch 1:  11%|█▏        | 160/1400 [01:07<09:17,  2.22it/s]
# Baseline Epoch 1:  12%|█▏        | 161/1400 [01:07<08:30,  2.42it/s]
# Baseline Epoch 1:  12%|█▏        | 162/1400 [01:08<08:55,  2.31it/s]
# Baseline Epoch 1:  12%|█▏        | 163/1400 [01:08<08:03,  2.56it/s]
# Baseline Epoch 1:  12%|█▏        | 164/1400 [01:08<07:47,  2.65it/s]
# Baseline Epoch 1:  12%|█▏        | 165/1400 [01:09<10:56,  1.88it/s]
# Baseline Epoch 1:  12%|█▏        | 166/1400 [01:10<10:25,  1.97it/s]
# Baseline Epoch 1:  12%|█▏        | 167/1400 [01:10<09:39,  2.13it/s]
# Baseline Epoch 1:  12%|█▏        | 168/1400 [01:10<09:18,  2.21it/s]
# Baseline Epoch 1:  12%|█▏        | 169/1400 [01:11<09:17,  2.21it/s]
# Baseline Epoch 1:  12%|█▏        | 170/1400 [01:11<08:55,  2.29it/s]
# Baseline Epoch 1:  12%|█▏        | 171/1400 [01:12<08:28,  2.42it/s]
# Baseline Epoch 1:  12%|█▏        | 172/1400 [01:12<09:23,  2.18it/s]
# Baseline Epoch 1:  12%|█▏        | 173/1400 [01:13<08:55,  2.29it/s]
# Baseline Epoch 1:  12%|█▏        | 174/1400 [01:13<09:11,  2.22it/s]
# Baseline Epoch 1:  12%|█▎        | 175/1400 [01:13<08:14,  2.48it/s]
# Baseline Epoch 1:  13%|█▎        | 176/1400 [01:14<08:05,  2.52it/s]
# Baseline Epoch 1:  13%|█▎        | 177/1400 [01:14<07:37,  2.68it/s]
# Baseline Epoch 1:  13%|█▎        | 178/1400 [01:14<07:20,  2.77it/s]
# Baseline Epoch 1:  13%|█▎        | 179/1400 [01:15<07:19,  2.78it/s]
# Baseline Epoch 1:  13%|█▎        | 180/1400 [01:15<07:16,  2.80it/s]
# Baseline Epoch 1:  13%|█▎        | 181/1400 [01:16<07:45,  2.62it/s]
# Baseline Epoch 1:  13%|█▎        | 182/1400 [01:16<09:02,  2.25it/s]
# Baseline Epoch 1:  13%|█▎        | 183/1400 [01:17<09:05,  2.23it/s]
# Baseline Epoch 1:  13%|█▎        | 184/1400 [01:17<09:59,  2.03it/s]
# Baseline Epoch 1:  13%|█▎        | 185/1400 [01:18<09:23,  2.16it/s]
# Baseline Epoch 1:  13%|█▎        | 186/1400 [01:18<08:41,  2.33it/s]
# Baseline Epoch 1:  13%|█▎        | 187/1400 [01:18<08:30,  2.38it/s]
# Baseline Epoch 1:  13%|█▎        | 188/1400 [01:19<08:35,  2.35it/s]
# Baseline Epoch 1:  14%|█▎        | 189/1400 [01:19<08:54,  2.26it/s]
# Baseline Epoch 1:  14%|█▎        | 190/1400 [01:20<08:45,  2.30it/s]
# Baseline Epoch 1:  14%|█▎        | 191/1400 [01:20<08:34,  2.35it/s]
# Baseline Epoch 1:  14%|█▎        | 192/1400 [01:20<08:16,  2.43it/s]
# Baseline Epoch 1:  14%|█▍        | 193/1400 [01:21<07:36,  2.64it/s]
# Baseline Epoch 1:  14%|█▍        | 194/1400 [01:21<07:37,  2.64it/s]
# Baseline Epoch 1:  14%|█▍        | 195/1400 [01:21<07:27,  2.69it/s]
# Baseline Epoch 1:  14%|█▍        | 196/1400 [01:22<07:19,  2.74it/s]
# Baseline Epoch 1:  14%|█▍        | 197/1400 [01:22<07:12,  2.78it/s]
# Baseline Epoch 1:  14%|█▍        | 198/1400 [01:22<07:04,  2.83it/s]
# Baseline Epoch 1:  14%|█▍        | 199/1400 [01:23<06:56,  2.88it/s]
# Baseline Epoch 1:  14%|█▍        | 200/1400 [01:23<07:05,  2.82it/s]
# Baseline Epoch 1:  14%|█▍        | 201/1400 [01:24<07:01,  2.85it/s]
# Baseline Epoch 1:  14%|█▍        | 202/1400 [01:24<07:11,  2.78it/s]
# Baseline Epoch 1:  14%|█▍        | 203/1400 [01:24<07:16,  2.74it/s]
# Baseline Epoch 1:  15%|█▍        | 204/1400 [01:25<07:10,  2.78it/s]
# Baseline Epoch 1:  15%|█▍        | 205/1400 [01:25<07:53,  2.52it/s]
# Baseline Epoch 1:  15%|█▍        | 206/1400 [01:26<08:35,  2.32it/s]
# Baseline Epoch 1:  15%|█▍        | 207/1400 [01:26<08:19,  2.39it/s]
# Baseline Epoch 1:  15%|█▍        | 208/1400 [01:26<08:19,  2.38it/s]
# Baseline Epoch 1:  15%|█▍        | 209/1400 [01:27<09:11,  2.16it/s]
# Baseline Epoch 1:  15%|█▌        | 210/1400 [01:27<08:26,  2.35it/s]
# Baseline Epoch 1:  15%|█▌        | 211/1400 [01:28<07:45,  2.55it/s]
# Baseline Epoch 1:  15%|█▌        | 212/1400 [01:28<08:00,  2.47it/s]
# Baseline Epoch 1:  15%|█▌        | 213/1400 [01:28<07:40,  2.58it/s]
# Baseline Epoch 1:  15%|█▌        | 214/1400 [01:29<07:25,  2.66it/s]
# Baseline Epoch 1:  15%|█▌        | 215/1400 [01:29<07:53,  2.50it/s]
# Baseline Epoch 1:  15%|█▌        | 216/1400 [01:30<07:38,  2.58it/s]
# Baseline Epoch 1:  16%|█▌        | 217/1400 [01:30<07:06,  2.77it/s]
# Baseline Epoch 1:  16%|█▌        | 218/1400 [01:30<06:53,  2.86it/s]
# Baseline Epoch 1:  16%|█▌        | 219/1400 [01:31<07:07,  2.76it/s]
# Baseline Epoch 1:  16%|█▌        | 220/1400 [01:31<09:01,  2.18it/s]
# Baseline Epoch 1:  16%|█▌        | 221/1400 [01:32<08:32,  2.30it/s]
# Baseline Epoch 1:  16%|█▌        | 222/1400 [01:32<07:47,  2.52it/s]
# Baseline Epoch 1:  16%|█▌        | 223/1400 [01:32<07:58,  2.46it/s]
# Baseline Epoch 1:  16%|█▌        | 224/1400 [01:33<07:56,  2.47it/s]
# Baseline Epoch 1:  16%|█▌        | 225/1400 [01:33<08:29,  2.30it/s]
# Baseline Epoch 1:  16%|█▌        | 226/1400 [01:34<08:27,  2.31it/s]
# Baseline Epoch 1:  16%|█▌        | 227/1400 [01:34<08:00,  2.44it/s]
# Baseline Epoch 1:  16%|█▋        | 228/1400 [01:35<08:01,  2.43it/s]
# Baseline Epoch 1:  16%|█▋        | 229/1400 [01:35<07:37,  2.56it/s]
# Baseline Epoch 1:  16%|█▋        | 230/1400 [01:35<07:25,  2.63it/s]
# Baseline Epoch 1:  16%|█▋        | 231/1400 [01:36<07:14,  2.69it/s]
# Baseline Epoch 1:  17%|█▋        | 232/1400 [01:36<07:10,  2.71it/s]
# Baseline Epoch 1:  17%|█▋        | 233/1400 [01:36<07:15,  2.68it/s]
# Baseline Epoch 1:  17%|█▋        | 234/1400 [01:37<08:02,  2.42it/s]
# Baseline Epoch 1:  17%|█▋        | 235/1400 [01:37<08:21,  2.32it/s]
# Baseline Epoch 1:  17%|█▋        | 236/1400 [01:38<08:22,  2.32it/s]
# Baseline Epoch 1:  17%|█▋        | 237/1400 [01:38<08:10,  2.37it/s]
# Baseline Epoch 1:  17%|█▋        | 238/1400 [01:39<07:55,  2.44it/s]
# Baseline Epoch 1:  17%|█▋        | 239/1400 [01:39<08:17,  2.33it/s]
# Baseline Epoch 1:  17%|█▋        | 240/1400 [01:39<07:36,  2.54it/s]
# Baseline Epoch 1:  17%|█▋        | 241/1400 [01:40<07:38,  2.53it/s]
# Baseline Epoch 1:  17%|█▋        | 242/1400 [01:40<08:34,  2.25it/s]
# Baseline Epoch 1:  17%|█▋        | 243/1400 [01:41<08:34,  2.25it/s]
# Baseline Epoch 1:  17%|█▋        | 244/1400 [01:41<08:12,  2.35it/s]
# Baseline Epoch 1:  18%|█▊        | 245/1400 [01:41<07:49,  2.46it/s]
# Baseline Epoch 1:  18%|█▊        | 246/1400 [01:42<07:44,  2.48it/s]
# Baseline Epoch 1:  18%|█▊        | 247/1400 [01:42<07:35,  2.53it/s]
# Baseline Epoch 1:  18%|█▊        | 248/1400 [01:43<07:49,  2.45it/s]
# Baseline Epoch 1:  18%|█▊        | 249/1400 [01:43<07:29,  2.56it/s]
# Baseline Epoch 1:  18%|█▊        | 250/1400 [01:43<07:59,  2.40it/s]
# Baseline Epoch 1:  18%|█▊        | 251/1400 [01:44<07:54,  2.42it/s]
# Baseline Epoch 1:  18%|█▊        | 252/1400 [01:44<07:48,  2.45it/s]
# Baseline Epoch 1:  18%|█▊        | 253/1400 [01:45<07:52,  2.43it/s]
# Baseline Epoch 1:  18%|█▊        | 254/1400 [01:45<08:13,  2.32it/s]
# Baseline Epoch 1:  18%|█▊        | 255/1400 [01:46<07:55,  2.41it/s]
# Baseline Epoch 1:  18%|█▊        | 256/1400 [01:46<07:40,  2.48it/s]
# Baseline Epoch 1:  18%|█▊        | 257/1400 [01:46<07:30,  2.54it/s]
# Baseline Epoch 1:  18%|█▊        | 258/1400 [01:47<07:34,  2.51it/s]
# Baseline Epoch 1:  18%|█▊        | 259/1400 [01:47<07:18,  2.60it/s]
# Baseline Epoch 1:  19%|█▊        | 260/1400 [01:48<08:38,  2.20it/s]
# Baseline Epoch 1:  19%|█▊        | 261/1400 [01:48<08:46,  2.16it/s]
# Baseline Epoch 1:  19%|█▊        | 262/1400 [01:49<08:19,  2.28it/s]
# Baseline Epoch 1:  19%|█▉        | 263/1400 [01:49<08:59,  2.11it/s]
# Baseline Epoch 1:  19%|█▉        | 264/1400 [01:49<08:02,  2.35it/s]
# Baseline Epoch 1:  19%|█▉        | 265/1400 [01:50<08:14,  2.30it/s]
# Baseline Epoch 1:  19%|█▉        | 266/1400 [01:50<08:15,  2.29it/s]
# Baseline Epoch 1:  19%|█▉        | 267/1400 [01:51<07:53,  2.39it/s]
# Baseline Epoch 1:  19%|█▉        | 268/1400 [01:51<08:14,  2.29it/s]
# Baseline Epoch 1:  19%|█▉        | 269/1400 [01:52<08:15,  2.28it/s]
# Baseline Epoch 1:  19%|█▉        | 270/1400 [01:52<08:56,  2.11it/s]
# Baseline Epoch 1:  19%|█▉        | 271/1400 [01:53<08:19,  2.26it/s]
# Baseline Epoch 1:  19%|█▉        | 272/1400 [01:53<07:57,  2.36it/s]
# Baseline Epoch 1:  20%|█▉        | 273/1400 [01:53<08:01,  2.34it/s]
# Baseline Epoch 1:  20%|█▉        | 274/1400 [01:54<07:23,  2.54it/s]
# Baseline Epoch 1:  20%|█▉        | 275/1400 [01:54<07:24,  2.53it/s]
# Baseline Epoch 1:  20%|█▉        | 276/1400 [01:54<07:05,  2.64it/s]
# Baseline Epoch 1:  20%|█▉        | 277/1400 [01:55<07:10,  2.61it/s]
# Baseline Epoch 1:  20%|█▉        | 278/1400 [01:55<07:20,  2.55it/s]
# Baseline Epoch 1:  20%|█▉        | 279/1400 [01:56<07:34,  2.47it/s]
# Baseline Epoch 1:  20%|██        | 280/1400 [01:56<07:17,  2.56it/s]
# Baseline Epoch 1:  20%|██        | 281/1400 [01:57<08:07,  2.30it/s]
# Baseline Epoch 1:  20%|██        | 282/1400 [01:57<08:11,  2.27it/s]
# Baseline Epoch 1:  20%|██        | 283/1400 [01:57<08:16,  2.25it/s]
# Baseline Epoch 1:  20%|██        | 284/1400 [01:58<07:47,  2.39it/s]
# Baseline Epoch 1:  20%|██        | 285/1400 [01:58<08:14,  2.25it/s]
# Baseline Epoch 1:  20%|██        | 286/1400 [01:59<09:12,  2.02it/s]
# Baseline Epoch 1:  20%|██        | 287/1400 [01:59<08:01,  2.31it/s]
# Baseline Epoch 1:  21%|██        | 288/1400 [02:00<07:30,  2.47it/s]
# Baseline Epoch 1:  21%|██        | 289/1400 [02:00<07:05,  2.61it/s]
# Baseline Epoch 1:  21%|██        | 290/1400 [02:00<07:20,  2.52it/s]
# Baseline Epoch 1:  21%|██        | 291/1400 [02:01<06:56,  2.67it/s]
# Baseline Epoch 1:  21%|██        | 292/1400 [02:01<07:13,  2.56it/s]
# Baseline Epoch 1:  21%|██        | 293/1400 [02:02<08:10,  2.26it/s]
# Baseline Epoch 1:  21%|██        | 294/1400 [02:02<07:49,  2.36it/s]
# Baseline Epoch 1:  21%|██        | 295/1400 [02:02<07:55,  2.33it/s]
# Baseline Epoch 1:  21%|██        | 296/1400 [02:03<08:03,  2.28it/s]
# Baseline Epoch 1:  21%|██        | 297/1400 [02:03<07:28,  2.46it/s]
# Baseline Epoch 1:  21%|██▏       | 298/1400 [02:04<07:13,  2.54it/s]
# Baseline Epoch 1:  21%|██▏       | 299/1400 [02:04<08:34,  2.14it/s]
# Baseline Epoch 1:  21%|██▏       | 300/1400 [02:05<07:44,  2.37it/s]
# Baseline Epoch 1:  22%|██▏       | 301/1400 [02:05<07:23,  2.48it/s]
# Baseline Epoch 1:  22%|██▏       | 302/1400 [02:05<07:26,  2.46it/s]
# Baseline Epoch 1:  22%|██▏       | 303/1400 [02:06<07:51,  2.33it/s]
# Baseline Epoch 1:  22%|██▏       | 304/1400 [02:06<07:55,  2.31it/s]
# Baseline Epoch 1:  22%|██▏       | 305/1400 [02:07<07:38,  2.39it/s]
# Baseline Epoch 1:  22%|██▏       | 306/1400 [02:07<07:16,  2.50it/s]
# Baseline Epoch 1:  22%|██▏       | 307/1400 [02:07<06:59,  2.60it/s]
# Baseline Epoch 1:  22%|██▏       | 308/1400 [02:08<06:42,  2.71it/s]
# Baseline Epoch 1:  22%|██▏       | 309/1400 [02:08<06:33,  2.77it/s]
# Baseline Epoch 1:  22%|██▏       | 310/1400 [02:08<07:02,  2.58it/s]
# Baseline Epoch 1:  22%|██▏       | 311/1400 [02:09<06:38,  2.73it/s]
# Baseline Epoch 1:  22%|██▏       | 312/1400 [02:09<06:29,  2.80it/s]
# Baseline Epoch 1:  22%|██▏       | 313/1400 [02:09<06:13,  2.91it/s]
# Baseline Epoch 1:  22%|██▏       | 314/1400 [02:10<06:06,  2.96it/s]
# Baseline Epoch 1:  22%|██▎       | 315/1400 [02:10<06:20,  2.85it/s]
# Baseline Epoch 1:  23%|██▎       | 316/1400 [02:10<06:13,  2.90it/s]
# Baseline Epoch 1:  23%|██▎       | 317/1400 [02:11<06:08,  2.94it/s]
# Baseline Epoch 1:  23%|██▎       | 318/1400 [02:11<06:49,  2.64it/s]
# Baseline Epoch 1:  23%|██▎       | 319/1400 [02:12<07:20,  2.45it/s]
# Baseline Epoch 1:  23%|██▎       | 320/1400 [02:12<07:10,  2.51it/s]
# Baseline Epoch 1:  23%|██▎       | 321/1400 [02:12<07:00,  2.57it/s]
# Baseline Epoch 1:  23%|██▎       | 322/1400 [02:13<07:29,  2.40it/s]
# Baseline Epoch 1:  23%|██▎       | 323/1400 [02:14<08:20,  2.15it/s]
# Baseline Epoch 1:  23%|██▎       | 324/1400 [02:14<07:39,  2.34it/s]
# Baseline Epoch 1:  23%|██▎       | 325/1400 [02:14<07:47,  2.30it/s]
# Baseline Epoch 1:  23%|██▎       | 326/1400 [02:15<07:40,  2.33it/s]
# Baseline Epoch 1:  23%|██▎       | 327/1400 [02:15<08:11,  2.18it/s]
# Baseline Epoch 1:  23%|██▎       | 328/1400 [02:16<07:58,  2.24it/s]
# Baseline Epoch 1:  24%|██▎       | 329/1400 [02:16<07:19,  2.44it/s]
# Baseline Epoch 1:  24%|██▎       | 330/1400 [02:16<06:49,  2.62it/s]
# Baseline Epoch 1:  24%|██▎       | 331/1400 [02:17<07:58,  2.23it/s]
# Baseline Epoch 1:  24%|██▎       | 332/1400 [02:17<07:16,  2.45it/s]
# Baseline Epoch 1:  24%|██▍       | 333/1400 [02:18<06:44,  2.64it/s]
# Baseline Epoch 1:  24%|██▍       | 334/1400 [02:18<06:46,  2.62it/s]
# Baseline Epoch 1:  24%|██▍       | 335/1400 [02:19<07:50,  2.26it/s]
# Baseline Epoch 1:  24%|██▍       | 336/1400 [02:19<07:34,  2.34it/s]
# Baseline Epoch 1:  24%|██▍       | 337/1400 [02:19<07:47,  2.27it/s]
# Baseline Epoch 1:  24%|██▍       | 338/1400 [02:20<07:21,  2.41it/s]
# Baseline Epoch 1:  24%|██▍       | 339/1400 [02:20<07:16,  2.43it/s]
# Baseline Epoch 1:  24%|██▍       | 340/1400 [02:21<06:59,  2.53it/s]
# Baseline Epoch 1:  24%|██▍       | 341/1400 [02:21<07:18,  2.42it/s]
# Baseline Epoch 1:  24%|██▍       | 342/1400 [02:21<07:04,  2.49it/s]
# Baseline Epoch 1:  24%|██▍       | 343/1400 [02:22<07:11,  2.45it/s]
# Baseline Epoch 1:  25%|██▍       | 344/1400 [02:22<07:31,  2.34it/s]
# Baseline Epoch 1:  25%|██▍       | 345/1400 [02:23<07:06,  2.47it/s]
# Baseline Epoch 1:  25%|██▍       | 346/1400 [02:23<07:45,  2.27it/s]
# Baseline Epoch 1:  25%|██▍       | 347/1400 [02:24<07:36,  2.31it/s]
# Baseline Epoch 1:  25%|██▍       | 348/1400 [02:24<07:33,  2.32it/s]
# Baseline Epoch 1:  25%|██▍       | 349/1400 [02:24<07:17,  2.40it/s]
# Baseline Epoch 1:  25%|██▌       | 350/1400 [02:25<06:52,  2.55it/s]
# Baseline Epoch 1:  25%|██▌       | 351/1400 [02:25<06:33,  2.67it/s]
# Baseline Epoch 1:  25%|██▌       | 352/1400 [02:25<07:03,  2.47it/s]
# Baseline Epoch 1:  25%|██▌       | 353/1400 [02:26<06:43,  2.59it/s]
# Baseline Epoch 1:  25%|██▌       | 354/1400 [02:26<06:36,  2.64it/s]
# Baseline Epoch 1:  25%|██▌       | 355/1400 [02:27<06:13,  2.80it/s]
# Baseline Epoch 1:  25%|██▌       | 356/1400 [02:27<06:19,  2.75it/s]
# Baseline Epoch 1:  26%|██▌       | 357/1400 [02:27<06:31,  2.67it/s]
# Baseline Epoch 1:  26%|██▌       | 358/1400 [02:28<06:29,  2.68it/s]
# Baseline Epoch 1:  26%|██▌       | 359/1400 [02:28<06:18,  2.75it/s]
# Baseline Epoch 1:  26%|██▌       | 360/1400 [02:28<06:28,  2.68it/s]
# Baseline Epoch 1:  26%|██▌       | 361/1400 [02:29<07:14,  2.39it/s]
# Baseline Epoch 1:  26%|██▌       | 362/1400 [02:29<06:42,  2.58it/s]
# Baseline Epoch 1:  26%|██▌       | 363/1400 [02:30<06:20,  2.72it/s]
# Baseline Epoch 1:  26%|██▌       | 364/1400 [02:30<06:45,  2.56it/s]
# Baseline Epoch 1:  26%|██▌       | 365/1400 [02:31<07:25,  2.32it/s]
# Baseline Epoch 1:  26%|██▌       | 366/1400 [02:31<08:19,  2.07it/s]
# Baseline Epoch 1:  26%|██▌       | 367/1400 [02:31<07:28,  2.30it/s]
# Baseline Epoch 1:  26%|██▋       | 368/1400 [02:32<07:04,  2.43it/s]
# Baseline Epoch 1:  26%|██▋       | 369/1400 [02:32<06:45,  2.54it/s]
# Baseline Epoch 1:  26%|██▋       | 370/1400 [02:32<06:25,  2.67it/s]
# Baseline Epoch 1:  26%|██▋       | 371/1400 [02:33<06:13,  2.75it/s]
# Baseline Epoch 1:  27%|██▋       | 372/1400 [02:33<06:16,  2.73it/s]
# Baseline Epoch 1:  27%|██▋       | 373/1400 [02:34<06:31,  2.62it/s]
# Baseline Epoch 1:  27%|██▋       | 374/1400 [02:34<06:23,  2.68it/s]
# Baseline Epoch 1:  27%|██▋       | 375/1400 [02:34<06:08,  2.78it/s]
# Baseline Epoch 1:  27%|██▋       | 376/1400 [02:35<07:11,  2.37it/s]
# Baseline Epoch 1:  27%|██▋       | 377/1400 [02:35<06:37,  2.58it/s]
# Baseline Epoch 1:  27%|██▋       | 378/1400 [02:36<06:24,  2.66it/s]
# Baseline Epoch 1:  27%|██▋       | 379/1400 [02:36<07:46,  2.19it/s]
# Baseline Epoch 1:  27%|██▋       | 380/1400 [02:37<07:22,  2.31it/s]
# Baseline Epoch 1:  27%|██▋       | 381/1400 [02:37<07:49,  2.17it/s]
# Baseline Epoch 1:  27%|██▋       | 382/1400 [02:37<07:05,  2.40it/s]
# Baseline Epoch 1:  27%|██▋       | 383/1400 [02:38<08:04,  2.10it/s]
# Baseline Epoch 1:  27%|██▋       | 384/1400 [02:38<07:37,  2.22it/s]
# Baseline Epoch 1:  28%|██▊       | 385/1400 [02:39<08:07,  2.08it/s]
# Baseline Epoch 1:  28%|██▊       | 386/1400 [02:39<07:38,  2.21it/s]
# Baseline Epoch 1:  28%|██▊       | 387/1400 [02:40<07:11,  2.35it/s]
# Baseline Epoch 1:  28%|██▊       | 388/1400 [02:40<06:54,  2.44it/s]
# Baseline Epoch 1:  28%|██▊       | 389/1400 [02:40<06:36,  2.55it/s]
# Baseline Epoch 1:  28%|██▊       | 390/1400 [02:41<06:27,  2.60it/s]
# Baseline Epoch 1:  28%|██▊       | 391/1400 [02:41<06:38,  2.53it/s]
# Baseline Epoch 1:  28%|██▊       | 392/1400 [02:42<06:47,  2.47it/s]
# Baseline Epoch 1:  28%|██▊       | 393/1400 [02:42<06:54,  2.43it/s]
# Baseline Epoch 1:  28%|██▊       | 394/1400 [02:42<06:46,  2.48it/s]
# Baseline Epoch 1:  28%|██▊       | 395/1400 [02:43<06:48,  2.46it/s]
# Baseline Epoch 1:  28%|██▊       | 396/1400 [02:43<06:40,  2.50it/s]
# Baseline Epoch 1:  28%|██▊       | 397/1400 [02:44<06:40,  2.51it/s]
# Baseline Epoch 1:  28%|██▊       | 398/1400 [02:44<06:32,  2.55it/s]
# Baseline Epoch 1:  28%|██▊       | 399/1400 [02:45<07:06,  2.35it/s]
# Baseline Epoch 1:  29%|██▊       | 400/1400 [02:45<07:08,  2.33it/s]
# Baseline Epoch 1:  29%|██▊       | 401/1400 [02:45<06:34,  2.53it/s]
# Baseline Epoch 1:  29%|██▊       | 402/1400 [02:46<06:29,  2.57it/s]
# Baseline Epoch 1:  29%|██▉       | 403/1400 [02:46<06:24,  2.60it/s]
# Baseline Epoch 1:  29%|██▉       | 404/1400 [02:47<07:15,  2.29it/s]
# Baseline Epoch 1:  29%|██▉       | 405/1400 [02:47<07:30,  2.21it/s]
# Baseline Epoch 1:  29%|██▉       | 406/1400 [02:48<07:25,  2.23it/s]
# Baseline Epoch 1:  29%|██▉       | 407/1400 [02:48<07:18,  2.26it/s]
# Baseline Epoch 1:  29%|██▉       | 408/1400 [02:48<06:56,  2.38it/s]
# Baseline Epoch 1:  29%|██▉       | 409/1400 [02:49<06:29,  2.55it/s]
# Baseline Epoch 1:  29%|██▉       | 410/1400 [02:49<06:14,  2.64it/s]
# Baseline Epoch 1:  29%|██▉       | 411/1400 [02:49<06:19,  2.60it/s]
# Baseline Epoch 1:  29%|██▉       | 412/1400 [02:50<06:26,  2.56it/s]
# Baseline Epoch 1:  30%|██▉       | 413/1400 [02:50<06:34,  2.50it/s]
# Baseline Epoch 1:  30%|██▉       | 414/1400 [02:51<06:07,  2.68it/s]
# Baseline Epoch 1:  30%|██▉       | 415/1400 [02:51<06:10,  2.66it/s]
# Baseline Epoch 1:  30%|██▉       | 416/1400 [02:51<06:03,  2.71it/s]
# Baseline Epoch 1:  30%|██▉       | 417/1400 [02:52<06:13,  2.63it/s]
# Baseline Epoch 1:  30%|██▉       | 418/1400 [02:52<06:05,  2.68it/s]
# Baseline Epoch 1:  30%|██▉       | 419/1400 [02:52<06:26,  2.54it/s]
# Baseline Epoch 1:  30%|███       | 420/1400 [02:53<06:07,  2.66it/s]
# Baseline Epoch 1:  30%|███       | 421/1400 [02:53<05:59,  2.73it/s]
# Baseline Epoch 1:  30%|███       | 422/1400 [02:53<05:47,  2.81it/s]
# Baseline Epoch 1:  30%|███       | 423/1400 [02:54<05:57,  2.73it/s]
# Baseline Epoch 1:  30%|███       | 424/1400 [02:54<06:03,  2.68it/s]
# Baseline Epoch 1:  30%|███       | 425/1400 [02:55<06:33,  2.48it/s]
# Baseline Epoch 1:  30%|███       | 426/1400 [02:55<07:43,  2.10it/s]
# Baseline Epoch 1:  30%|███       | 427/1400 [02:56<06:55,  2.34it/s]
# Baseline Epoch 1:  31%|███       | 428/1400 [02:56<06:57,  2.33it/s]
# Baseline Epoch 1:  31%|███       | 429/1400 [02:57<06:55,  2.34it/s]
# Baseline Epoch 1:  31%|███       | 430/1400 [02:57<06:17,  2.57it/s]
# Baseline Epoch 1:  31%|███       | 431/1400 [02:57<06:30,  2.48it/s]
# Baseline Epoch 1:  31%|███       | 432/1400 [02:58<06:10,  2.61it/s]
# Baseline Epoch 1:  31%|███       | 433/1400 [02:58<05:49,  2.76it/s]
# Baseline Epoch 1:  31%|███       | 434/1400 [02:58<06:01,  2.68it/s]
# Baseline Epoch 1:  31%|███       | 435/1400 [02:59<06:25,  2.50it/s]
# Baseline Epoch 1:  31%|███       | 436/1400 [02:59<05:59,  2.68it/s]
# Baseline Epoch 1:  31%|███       | 437/1400 [02:59<05:55,  2.71it/s]
# Baseline Epoch 1:  31%|███▏      | 438/1400 [03:00<05:58,  2.68it/s]
# Baseline Epoch 1:  31%|███▏      | 439/1400 [03:00<05:49,  2.75it/s]
# Baseline Epoch 1:  31%|███▏      | 440/1400 [03:01<06:14,  2.56it/s]
# Baseline Epoch 1:  32%|███▏      | 441/1400 [03:01<06:18,  2.54it/s]
# Baseline Epoch 1:  32%|███▏      | 442/1400 [03:01<06:08,  2.60it/s]
# Baseline Epoch 1:  32%|███▏      | 443/1400 [03:02<06:12,  2.57it/s]
# Baseline Epoch 1:  32%|███▏      | 444/1400 [03:02<06:08,  2.59it/s]
# Baseline Epoch 1:  32%|███▏      | 445/1400 [03:03<06:16,  2.53it/s]
# Baseline Epoch 1:  32%|███▏      | 446/1400 [03:03<06:12,  2.56it/s]
# Baseline Epoch 1:  32%|███▏      | 447/1400 [03:03<05:57,  2.66it/s]
# Baseline Epoch 1:  32%|███▏      | 448/1400 [03:04<05:59,  2.65it/s]
# Baseline Epoch 1:  32%|███▏      | 449/1400 [03:04<05:58,  2.66it/s]
# Baseline Epoch 1:  32%|███▏      | 450/1400 [03:05<06:50,  2.31it/s]
# Baseline Epoch 1:  32%|███▏      | 451/1400 [03:05<06:25,  2.46it/s]
# Baseline Epoch 1:  32%|███▏      | 452/1400 [03:05<06:36,  2.39it/s]
# Baseline Epoch 1:  32%|███▏      | 453/1400 [03:06<06:24,  2.46it/s]
# Baseline Epoch 1:  32%|███▏      | 454/1400 [03:06<06:38,  2.37it/s]
# Baseline Epoch 1:  32%|███▎      | 455/1400 [03:07<06:42,  2.35it/s]
# Baseline Epoch 1:  33%|███▎      | 456/1400 [03:07<06:25,  2.45it/s]
# Baseline Epoch 1:  33%|███▎      | 457/1400 [03:07<06:09,  2.55it/s]
# Baseline Epoch 1:  33%|███▎      | 458/1400 [03:08<06:12,  2.53it/s]
# Baseline Epoch 1:  33%|███▎      | 459/1400 [03:08<06:30,  2.41it/s]
# Baseline Epoch 1:  33%|███▎      | 460/1400 [03:09<06:28,  2.42it/s]
# Baseline Epoch 1:  33%|███▎      | 461/1400 [03:09<06:50,  2.29it/s]
# Baseline Epoch 1:  33%|███▎      | 462/1400 [03:10<07:16,  2.15it/s]
# Baseline Epoch 1:  33%|███▎      | 463/1400 [03:10<07:07,  2.19it/s]
# Baseline Epoch 1:  33%|███▎      | 464/1400 [03:11<07:01,  2.22it/s]
# Baseline Epoch 1:  33%|███▎      | 465/1400 [03:11<06:39,  2.34it/s]
# Baseline Epoch 1:  33%|███▎      | 466/1400 [03:11<06:25,  2.42it/s]
# Baseline Epoch 1:  33%|███▎      | 467/1400 [03:12<06:04,  2.56it/s]
# Baseline Epoch 1:  33%|███▎      | 468/1400 [03:12<05:45,  2.70it/s]
# Baseline Epoch 1:  34%|███▎      | 469/1400 [03:12<05:34,  2.79it/s]
# Baseline Epoch 1:  34%|███▎      | 470/1400 [03:13<05:31,  2.80it/s]
# Baseline Epoch 1:  34%|███▎      | 471/1400 [03:13<05:54,  2.62it/s]
# Baseline Epoch 1:  34%|███▎      | 472/1400 [03:14<06:10,  2.50it/s]
# Baseline Epoch 1:  34%|███▍      | 473/1400 [03:14<05:58,  2.59it/s]
# Baseline Epoch 1:  34%|███▍      | 474/1400 [03:14<06:11,  2.50it/s]
# Baseline Epoch 1:  34%|███▍      | 475/1400 [03:15<06:26,  2.39it/s]
# Baseline Epoch 1:  34%|███▍      | 476/1400 [03:15<06:13,  2.47it/s]
# Baseline Epoch 1:  34%|███▍      | 477/1400 [03:15<05:43,  2.69it/s]
# Baseline Epoch 1:  34%|███▍      | 478/1400 [03:16<06:26,  2.39it/s]
# Baseline Epoch 1:  34%|███▍      | 479/1400 [03:16<05:57,  2.57it/s]
# Baseline Epoch 1:  34%|███▍      | 480/1400 [03:17<06:00,  2.55it/s]
# Baseline Epoch 1:  34%|███▍      | 481/1400 [03:17<06:43,  2.28it/s]
# Baseline Epoch 1:  34%|███▍      | 482/1400 [03:18<06:49,  2.24it/s]
# Baseline Epoch 1:  34%|███▍      | 483/1400 [03:18<06:45,  2.26it/s]
# Baseline Epoch 1:  35%|███▍      | 484/1400 [03:18<06:03,  2.52it/s]
# Baseline Epoch 1:  35%|███▍      | 485/1400 [03:19<05:58,  2.55it/s]
# Baseline Epoch 1:  35%|███▍      | 486/1400 [03:19<05:32,  2.75it/s]
# Baseline Epoch 1:  35%|███▍      | 487/1400 [03:19<05:27,  2.78it/s]
# Baseline Epoch 1:  35%|███▍      | 488/1400 [03:20<05:38,  2.70it/s]
# Baseline Epoch 1:  35%|███▍      | 489/1400 [03:20<06:13,  2.44it/s]
# Baseline Epoch 1:  35%|███▌      | 490/1400 [03:21<06:25,  2.36it/s]
# Baseline Epoch 1:  35%|███▌      | 491/1400 [03:21<05:57,  2.54it/s]
# Baseline Epoch 1:  35%|███▌      | 492/1400 [03:21<05:37,  2.69it/s]
# Baseline Epoch 1:  35%|███▌      | 493/1400 [03:22<05:43,  2.64it/s]
# Baseline Epoch 1:  35%|███▌      | 494/1400 [03:22<05:48,  2.60it/s]
# Baseline Epoch 1:  35%|███▌      | 495/1400 [03:23<06:06,  2.47it/s]
# Baseline Epoch 1:  35%|███▌      | 496/1400 [03:23<06:14,  2.42it/s]
# Baseline Epoch 1:  36%|███▌      | 497/1400 [03:24<05:56,  2.54it/s]
# Baseline Epoch 1:  36%|███▌      | 498/1400 [03:24<05:44,  2.62it/s]
# Baseline Epoch 1:  36%|███▌      | 499/1400 [03:24<05:50,  2.57it/s]
# Baseline Epoch 1:  36%|███▌      | 500/1400 [03:25<05:48,  2.58it/s]
# Baseline Epoch 1:  36%|███▌      | 501/1400 [03:25<05:45,  2.60it/s]
# Baseline Epoch 1:  36%|███▌      | 502/1400 [03:25<05:55,  2.53it/s]
# Baseline Epoch 1:  36%|███▌      | 503/1400 [03:26<05:55,  2.52it/s]
# Baseline Epoch 1:  36%|███▌      | 504/1400 [03:26<05:52,  2.54it/s]
# Baseline Epoch 1:  36%|███▌      | 505/1400 [03:27<06:05,  2.45it/s]
# Baseline Epoch 1:  36%|███▌      | 506/1400 [03:27<06:50,  2.18it/s]
# Baseline Epoch 1:  36%|███▌      | 507/1400 [03:28<06:14,  2.38it/s]
# Baseline Epoch 1:  36%|███▋      | 508/1400 [03:28<06:29,  2.29it/s]
# Baseline Epoch 1:  36%|███▋      | 509/1400 [03:28<06:21,  2.34it/s]
# Baseline Epoch 1:  36%|███▋      | 510/1400 [03:29<06:05,  2.44it/s]
# Baseline Epoch 1:  36%|███▋      | 511/1400 [03:29<05:46,  2.57it/s]
# Baseline Epoch 1:  37%|███▋      | 512/1400 [03:30<06:28,  2.28it/s]
# Baseline Epoch 1:  37%|███▋      | 513/1400 [03:30<06:22,  2.32it/s]
# Baseline Epoch 1:  37%|███▋      | 514/1400 [03:31<06:47,  2.18it/s]
# Baseline Epoch 1:  37%|███▋      | 515/1400 [03:31<06:36,  2.23it/s]
# Baseline Epoch 1:  37%|███▋      | 516/1400 [03:31<06:22,  2.31it/s]
# Baseline Epoch 1:  37%|███▋      | 517/1400 [03:32<06:12,  2.37it/s]
# Baseline Epoch 1:  37%|███▋      | 518/1400 [03:32<06:40,  2.20it/s]
# Baseline Epoch 1:  37%|███▋      | 519/1400 [03:33<06:21,  2.31it/s]
# Baseline Epoch 1:  37%|███▋      | 520/1400 [03:33<06:28,  2.27it/s]
# Baseline Epoch 1:  37%|███▋      | 521/1400 [03:34<05:55,  2.47it/s]
# Baseline Epoch 1:  37%|███▋      | 522/1400 [03:34<06:02,  2.42it/s]
# Baseline Epoch 1:  37%|███▋      | 523/1400 [03:34<05:43,  2.55it/s]
# Baseline Epoch 1:  37%|███▋      | 524/1400 [03:35<05:57,  2.45it/s]
# Baseline Epoch 1:  38%|███▊      | 525/1400 [03:35<05:27,  2.67it/s]
# Baseline Epoch 1:  38%|███▊      | 526/1400 [03:35<05:28,  2.66it/s]
# Baseline Epoch 1:  38%|███▊      | 527/1400 [03:36<05:10,  2.81it/s]
# Baseline Epoch 1:  38%|███▊      | 528/1400 [03:36<05:15,  2.77it/s]
# Baseline Epoch 1:  38%|███▊      | 529/1400 [03:37<05:25,  2.68it/s]
# Baseline Epoch 1:  38%|███▊      | 530/1400 [03:37<05:26,  2.66it/s]
# Baseline Epoch 1:  38%|███▊      | 531/1400 [03:37<05:36,  2.58it/s]
# Baseline Epoch 1:  38%|███▊      | 532/1400 [03:38<05:33,  2.60it/s]
# Baseline Epoch 1:  38%|███▊      | 533/1400 [03:38<05:11,  2.78it/s]
# Baseline Epoch 1:  38%|███▊      | 534/1400 [03:38<05:17,  2.73it/s]
# Baseline Epoch 1:  38%|███▊      | 535/1400 [03:39<05:42,  2.53it/s]
# Baseline Epoch 1:  38%|███▊      | 536/1400 [03:39<05:40,  2.54it/s]
# Baseline Epoch 1:  38%|███▊      | 537/1400 [03:40<05:45,  2.50it/s]
# Baseline Epoch 1:  38%|███▊      | 538/1400 [03:40<05:51,  2.45it/s]
# Baseline Epoch 1:  38%|███▊      | 539/1400 [03:41<06:13,  2.31it/s]
# Baseline Epoch 1:  39%|███▊      | 540/1400 [03:41<05:50,  2.46it/s]
# Baseline Epoch 1:  39%|███▊      | 541/1400 [03:41<05:52,  2.44it/s]
# Baseline Epoch 1:  39%|███▊      | 542/1400 [03:42<06:01,  2.38it/s]
# Baseline Epoch 1:  39%|███▉      | 543/1400 [03:42<05:34,  2.56it/s]
# Baseline Epoch 1:  39%|███▉      | 544/1400 [03:42<05:26,  2.63it/s]
# Baseline Epoch 1:  39%|███▉      | 545/1400 [03:43<05:30,  2.58it/s]
# Baseline Epoch 1:  39%|███▉      | 546/1400 [03:43<05:33,  2.56it/s]
# Baseline Epoch 1:  39%|███▉      | 547/1400 [03:44<05:42,  2.49it/s]
# Baseline Epoch 1:  39%|███▉      | 548/1400 [03:44<05:32,  2.57it/s]
# Baseline Epoch 1:  39%|███▉      | 549/1400 [03:44<05:05,  2.78it/s]
# Baseline Epoch 1:  39%|███▉      | 550/1400 [03:45<05:51,  2.42it/s]
# Baseline Epoch 1:  39%|███▉      | 551/1400 [03:45<05:47,  2.44it/s]
# Baseline Epoch 1:  39%|███▉      | 552/1400 [03:46<05:33,  2.54it/s]
# Baseline Epoch 1:  40%|███▉      | 553/1400 [03:46<05:15,  2.69it/s]
# Baseline Epoch 1:  40%|███▉      | 554/1400 [03:46<05:19,  2.65it/s]
# Baseline Epoch 1:  40%|███▉      | 555/1400 [03:47<05:06,  2.76it/s]
# Baseline Epoch 1:  40%|███▉      | 556/1400 [03:47<06:08,  2.29it/s]
# Baseline Epoch 1:  40%|███▉      | 557/1400 [03:48<05:35,  2.51it/s]
# Baseline Epoch 1:  40%|███▉      | 558/1400 [03:48<05:25,  2.58it/s]
# Baseline Epoch 1:  40%|███▉      | 559/1400 [03:49<06:06,  2.30it/s]
# Baseline Epoch 1:  40%|████      | 560/1400 [03:49<05:59,  2.34it/s]
# Baseline Epoch 1:  40%|████      | 561/1400 [03:49<05:59,  2.33it/s]
# Baseline Epoch 1:  40%|████      | 562/1400 [03:50<05:37,  2.48it/s]
# Baseline Epoch 1:  40%|████      | 563/1400 [03:50<05:33,  2.51it/s]
# Baseline Epoch 1:  40%|████      | 564/1400 [03:50<05:23,  2.58it/s]
# Baseline Epoch 1:  40%|████      | 565/1400 [03:51<05:15,  2.65it/s]
# Baseline Epoch 1:  40%|████      | 566/1400 [03:51<05:20,  2.60it/s]
# Baseline Epoch 1:  40%|████      | 567/1400 [03:52<05:20,  2.60it/s]
# Baseline Epoch 1:  41%|████      | 568/1400 [03:52<06:12,  2.23it/s]
# Baseline Epoch 1:  41%|████      | 569/1400 [03:53<06:20,  2.18it/s]
# Baseline Epoch 1:  41%|████      | 570/1400 [03:53<06:28,  2.14it/s]
# Baseline Epoch 1:  41%|████      | 571/1400 [03:54<06:00,  2.30it/s]
# Baseline Epoch 1:  41%|████      | 572/1400 [03:54<05:33,  2.48it/s]
# Baseline Epoch 1:  41%|████      | 573/1400 [03:54<05:14,  2.63it/s]
# Baseline Epoch 1:  41%|████      | 574/1400 [03:55<05:43,  2.41it/s]
# Baseline Epoch 1:  41%|████      | 575/1400 [03:55<05:11,  2.65it/s]
# Baseline Epoch 1:  41%|████      | 576/1400 [03:55<05:39,  2.43it/s]
# Baseline Epoch 1:  41%|████      | 577/1400 [03:56<06:18,  2.18it/s]
# Baseline Epoch 1:  41%|████▏     | 578/1400 [03:57<06:34,  2.08it/s]
# Baseline Epoch 1:  41%|████▏     | 579/1400 [03:57<06:14,  2.19it/s]
# Baseline Epoch 1:  41%|████▏     | 580/1400 [03:57<06:00,  2.28it/s]
# Baseline Epoch 1:  42%|████▏     | 581/1400 [03:58<06:07,  2.23it/s]
# Baseline Epoch 1:  42%|████▏     | 582/1400 [03:58<06:15,  2.18it/s]
# Baseline Epoch 1:  42%|████▏     | 583/1400 [03:59<05:51,  2.32it/s]
# Baseline Epoch 1:  42%|████▏     | 584/1400 [03:59<05:39,  2.40it/s]
# Baseline Epoch 1:  42%|████▏     | 585/1400 [03:59<05:25,  2.50it/s]
# Baseline Epoch 1:  42%|████▏     | 586/1400 [04:00<05:30,  2.46it/s]
# Baseline Epoch 1:  42%|████▏     | 587/1400 [04:00<05:15,  2.57it/s]
# Baseline Epoch 1:  42%|████▏     | 588/1400 [04:01<05:14,  2.58it/s]
# Baseline Epoch 1:  42%|████▏     | 589/1400 [04:01<05:06,  2.65it/s]
# Baseline Epoch 1:  42%|████▏     | 590/1400 [04:01<05:00,  2.70it/s]
# Baseline Epoch 1:  42%|████▏     | 591/1400 [04:02<05:57,  2.26it/s]
# Baseline Epoch 1:  42%|████▏     | 592/1400 [04:02<05:51,  2.30it/s]
# Baseline Epoch 1:  42%|████▏     | 593/1400 [04:03<05:41,  2.36it/s]
# Baseline Epoch 1:  42%|████▏     | 594/1400 [04:03<06:32,  2.06it/s]
# Baseline Epoch 1:  42%|████▎     | 595/1400 [04:04<05:56,  2.26it/s]
# Baseline Epoch 1:  43%|████▎     | 596/1400 [04:04<05:23,  2.49it/s]
# Baseline Epoch 1:  43%|████▎     | 597/1400 [04:04<05:14,  2.55it/s]
# Baseline Epoch 1:  43%|████▎     | 598/1400 [04:05<05:13,  2.56it/s]
# Baseline Epoch 1:  43%|████▎     | 599/1400 [04:05<05:19,  2.51it/s]
# Baseline Epoch 1:  43%|████▎     | 600/1400 [04:06<05:35,  2.39it/s]
# Baseline Epoch 1:  43%|████▎     | 601/1400 [04:06<05:54,  2.25it/s]
# Baseline Epoch 1:  43%|████▎     | 602/1400 [04:07<05:55,  2.25it/s]
# Baseline Epoch 1:  43%|████▎     | 603/1400 [04:07<06:01,  2.21it/s]
# Baseline Epoch 1:  43%|████▎     | 604/1400 [04:07<05:52,  2.26it/s]
# Baseline Epoch 1:  43%|████▎     | 605/1400 [04:08<06:13,  2.13it/s]
# Baseline Epoch 1:  43%|████▎     | 606/1400 [04:08<06:08,  2.15it/s]
# Baseline Epoch 1:  43%|████▎     | 607/1400 [04:09<05:52,  2.25it/s]
# Baseline Epoch 1:  43%|████▎     | 608/1400 [04:09<05:38,  2.34it/s]
# Baseline Epoch 1:  44%|████▎     | 609/1400 [04:10<05:20,  2.47it/s]
# Baseline Epoch 1:  44%|████▎     | 610/1400 [04:10<05:06,  2.58it/s]
# Baseline Epoch 1:  44%|████▎     | 611/1400 [04:10<05:01,  2.62it/s]
# Baseline Epoch 1:  44%|████▎     | 612/1400 [04:11<05:04,  2.59it/s]
# Baseline Epoch 1:  44%|████▍     | 613/1400 [04:11<05:12,  2.52it/s]
# Baseline Epoch 1:  44%|████▍     | 614/1400 [04:11<05:05,  2.57it/s]
# Baseline Epoch 1:  44%|████▍     | 615/1400 [04:12<05:47,  2.26it/s]
# Baseline Epoch 1:  44%|████▍     | 616/1400 [04:12<05:34,  2.34it/s]
# Baseline Epoch 1:  44%|████▍     | 617/1400 [04:13<05:26,  2.40it/s]
# Baseline Epoch 1:  44%|████▍     | 618/1400 [04:13<05:35,  2.33it/s]
# Baseline Epoch 1:  44%|████▍     | 619/1400 [04:14<05:29,  2.37it/s]
# Baseline Epoch 1:  44%|████▍     | 620/1400 [04:14<05:25,  2.40it/s]
# Baseline Epoch 1:  44%|████▍     | 621/1400 [04:15<05:17,  2.45it/s]
# Baseline Epoch 1:  44%|████▍     | 622/1400 [04:15<05:07,  2.53it/s]
# Baseline Epoch 1:  44%|████▍     | 623/1400 [04:15<05:52,  2.21it/s]
# Baseline Epoch 1:  45%|████▍     | 624/1400 [04:16<05:23,  2.40it/s]
# Baseline Epoch 1:  45%|████▍     | 625/1400 [04:16<05:34,  2.32it/s]
# ...
# Baseline Epoch 1:  85%|████████▌ | 1191/1400 [08:11<01:27,  2.39it/s]
# Baseline Epoch 1:  85%|████████▌ | 1192/1400 [08:11<01:24,  2.46it/s]
# Baseline Epoch 1:  85%|████████▌ | 1193/1400 [08:12<01:24,  2.46it/s]
# Baseline Epoch 1:  85%|████████▌ | 1194/1400 [08:12<01:22,  2.49it/s]
# Baseline Epoch 1:  85%|████████▌ | 1195/1400 [08:12<01:14,  2.73it/s]
# Baseline Epoch 1:  85%|████████▌ | 1196/1400 [08:13<01:13,  2.79it/s]
# Baseline Epoch 1:  86%|████████▌ | 1197/1400 [08:13<01:11,  2.84it/s]
# Baseline Epoch 1:  86%|████████▌ | 1198/1400 [08:13<01:11,  2.84it/s]
# Baseline Epoch 1:  86%|████████▌ | 1199/1400 [08:14<01:13,  2.74it/s]
# Baseline Epoch 1:  86%|████████▌ | 1200/1400 [08:14<01:25,  2.34it/s]
# Baseline Epoch 1:  86%|████████▌ | 1201/1400 [08:15<01:22,  2.40it/s]
# Baseline Epoch 1:  86%|████████▌ | 1202/1400 [08:15<01:21,  2.44it/s]
# Baseline Epoch 1:  86%|████████▌ | 1203/1400 [08:15<01:22,  2.38it/s]
# Baseline Epoch 1:  86%|████████▌ | 1204/1400 [08:16<01:22,  2.39it/s]
# Baseline Epoch 1:  86%|████████▌ | 1205/1400 [08:16<01:16,  2.54it/s]
# Baseline Epoch 1:  86%|████████▌ | 1206/1400 [08:17<01:18,  2.48it/s]
# Baseline Epoch 1:  86%|████████▌ | 1207/1400 [08:17<01:19,  2.43it/s]
# Baseline Epoch 1:  86%|████████▋ | 1208/1400 [08:18<01:20,  2.40it/s]
# Baseline Epoch 1:  86%|████████▋ | 1209/1400 [08:18<01:17,  2.47it/s]
# Baseline Epoch 1:  86%|████████▋ | 1210/1400 [08:18<01:14,  2.56it/s]
# Baseline Epoch 1:  86%|████████▋ | 1211/1400 [08:19<01:16,  2.47it/s]
# Baseline Epoch 1:  87%|████████▋ | 1212/1400 [08:19<01:14,  2.51it/s]
# Baseline Epoch 1:  87%|████████▋ | 1213/1400 [08:19<01:12,  2.58it/s]
# Baseline Epoch 1:  87%|████████▋ | 1214/1400 [08:20<01:12,  2.56it/s]
# Baseline Epoch 1:  87%|████████▋ | 1215/1400 [08:20<01:07,  2.72it/s]
# Baseline Epoch 1:  87%|████████▋ | 1216/1400 [08:21<01:10,  2.62it/s]
# Baseline Epoch 1:  87%|████████▋ | 1217/1400 [08:21<01:09,  2.64it/s]
# Baseline Epoch 1:  87%|████████▋ | 1218/1400 [08:21<01:07,  2.71it/s]
# Baseline Epoch 1:  87%|████████▋ | 1219/1400 [08:22<01:07,  2.68it/s]
# Baseline Epoch 1:  87%|████████▋ | 1220/1400 [08:22<01:08,  2.62it/s]
# Baseline Epoch 1:  87%|████████▋ | 1221/1400 [08:22<01:08,  2.62it/s]
# Baseline Epoch 1:  87%|████████▋ | 1222/1400 [08:23<01:20,  2.22it/s]
# Baseline Epoch 1:  87%|████████▋ | 1223/1400 [08:23<01:15,  2.35it/s]
# Baseline Epoch 1:  87%|████████▋ | 1224/1400 [08:24<01:15,  2.34it/s]
# Baseline Epoch 1:  88%|████████▊ | 1225/1400 [08:24<01:11,  2.45it/s]
# Baseline Epoch 1:  88%|████████▊ | 1226/1400 [08:25<01:08,  2.55it/s]
# Baseline Epoch 1:  88%|████████▊ | 1227/1400 [08:25<01:09,  2.48it/s]
# Baseline Epoch 1:  88%|████████▊ | 1228/1400 [08:25<01:09,  2.49it/s]
# Baseline Epoch 1:  88%|████████▊ | 1229/1400 [08:26<01:10,  2.43it/s]
# Baseline Epoch 1:  88%|████████▊ | 1230/1400 [08:26<01:04,  2.63it/s]
# Baseline Epoch 1:  88%|████████▊ | 1231/1400 [08:27<01:03,  2.68it/s]
# Baseline Epoch 1:  88%|████████▊ | 1232/1400 [08:27<01:02,  2.67it/s]
# Baseline Epoch 1:  88%|████████▊ | 1233/1400 [08:27<00:57,  2.90it/s]
# Baseline Epoch 1:  88%|████████▊ | 1234/1400 [08:28<01:06,  2.49it/s]
# Baseline Epoch 1:  88%|████████▊ | 1235/1400 [08:28<01:06,  2.49it/s]
# Baseline Epoch 1:  88%|████████▊ | 1236/1400 [08:28<01:04,  2.54it/s]
# Baseline Epoch 1:  88%|████████▊ | 1237/1400 [08:29<01:00,  2.71it/s]
# Baseline Epoch 1:  88%|████████▊ | 1238/1400 [08:29<01:13,  2.21it/s]
# Baseline Epoch 1:  88%|████████▊ | 1239/1400 [08:30<01:11,  2.26it/s]
# Baseline Epoch 1:  89%|████████▊ | 1240/1400 [08:30<01:10,  2.26it/s]
# Baseline Epoch 1:  89%|████████▊ | 1241/1400 [08:31<01:05,  2.42it/s]
# Baseline Epoch 1:  89%|████████▊ | 1242/1400 [08:31<01:09,  2.28it/s]
# Baseline Epoch 1:  89%|████████▉ | 1243/1400 [08:32<01:17,  2.02it/s]
# Baseline Epoch 1:  89%|████████▉ | 1244/1400 [08:32<01:10,  2.22it/s]
# Baseline Epoch 1:  89%|████████▉ | 1245/1400 [08:32<01:04,  2.41it/s]
# Baseline Epoch 1:  89%|████████▉ | 1246/1400 [08:33<01:00,  2.54it/s]
# Baseline Epoch 1:  89%|████████▉ | 1247/1400 [08:33<00:59,  2.58it/s]
# Baseline Epoch 1:  89%|████████▉ | 1248/1400 [08:33<00:55,  2.72it/s]
# Baseline Epoch 1:  89%|████████▉ | 1249/1400 [08:34<00:55,  2.72it/s]
# Baseline Epoch 1:  89%|████████▉ | 1250/1400 [08:34<00:56,  2.66it/s]
# Baseline Epoch 1:  89%|████████▉ | 1251/1400 [08:35<00:57,  2.61it/s]
# Baseline Epoch 1:  89%|████████▉ | 1252/1400 [08:35<00:54,  2.70it/s]
# Baseline Epoch 1:  90%|████████▉ | 1253/1400 [08:35<00:54,  2.70it/s]
# Baseline Epoch 1:  90%|████████▉ | 1254/1400 [08:36<01:01,  2.39it/s]
# Baseline Epoch 1:  90%|████████▉ | 1255/1400 [08:36<00:59,  2.44it/s]
# Baseline Epoch 1:  90%|████████▉ | 1256/1400 [08:37<00:59,  2.40it/s]
# Baseline Epoch 1:  90%|████████▉ | 1257/1400 [08:37<00:54,  2.62it/s]
# Baseline Epoch 1:  90%|████████▉ | 1258/1400 [08:37<00:55,  2.56it/s]
# Baseline Epoch 1:  90%|████████▉ | 1259/1400 [08:38<01:01,  2.28it/s]
# Baseline Epoch 1:  90%|█████████ | 1260/1400 [08:38<00:58,  2.39it/s]
# Baseline Epoch 1:  90%|█████████ | 1261/1400 [08:39<00:55,  2.49it/s]
# Baseline Epoch 1:  90%|█████████ | 1262/1400 [08:39<00:51,  2.68it/s]
# Baseline Epoch 1:  90%|█████████ | 1263/1400 [08:39<00:52,  2.62it/s]
# Baseline Epoch 1:  90%|█████████ | 1264/1400 [08:40<00:49,  2.76it/s]
# Baseline Epoch 1:  90%|█████████ | 1265/1400 [08:40<00:49,  2.73it/s]
# Baseline Epoch 1:  90%|█████████ | 1266/1400 [08:41<00:52,  2.54it/s]
# Baseline Epoch 1:  90%|█████████ | 1267/1400 [08:41<00:51,  2.61it/s]
# Baseline Epoch 1:  91%|█████████ | 1268/1400 [08:41<00:49,  2.65it/s]
# Baseline Epoch 1:  91%|█████████ | 1269/1400 [08:42<00:50,  2.57it/s]
# Baseline Epoch 1:  91%|█████████ | 1270/1400 [08:42<00:56,  2.31it/s]
# Baseline Epoch 1:  91%|█████████ | 1271/1400 [08:43<00:52,  2.46it/s]
# Baseline Epoch 1:  91%|█████████ | 1272/1400 [08:43<00:51,  2.47it/s]
# Baseline Epoch 1:  91%|█████████ | 1273/1400 [08:43<00:49,  2.59it/s]
# Baseline Epoch 1:  91%|█████████ | 1274/1400 [08:44<00:46,  2.71it/s]
# Baseline Epoch 1:  91%|█████████ | 1275/1400 [08:44<00:45,  2.75it/s]
# Baseline Epoch 1:  91%|█████████ | 1276/1400 [08:44<00:44,  2.78it/s]
# Baseline Epoch 1:  91%|█████████ | 1277/1400 [08:45<00:43,  2.80it/s]
# Baseline Epoch 1:  91%|█████████▏| 1278/1400 [08:45<00:44,  2.71it/s]
# Baseline Epoch 1:  91%|█████████▏| 1279/1400 [08:45<00:44,  2.74it/s]
# Baseline Epoch 1:  91%|█████████▏| 1280/1400 [08:46<00:43,  2.77it/s]
# Baseline Epoch 1:  92%|█████████▏| 1281/1400 [08:46<00:46,  2.58it/s]
# Baseline Epoch 1:  92%|█████████▏| 1282/1400 [08:47<00:42,  2.74it/s]
# Baseline Epoch 1:  92%|█████████▏| 1283/1400 [08:47<00:43,  2.71it/s]
# Baseline Epoch 1:  92%|█████████▏| 1284/1400 [08:47<00:39,  2.90it/s]
# Baseline Epoch 1:  92%|█████████▏| 1285/1400 [08:48<00:54,  2.09it/s]
# Baseline Epoch 1:  92%|█████████▏| 1286/1400 [08:48<00:50,  2.24it/s]
# Baseline Epoch 1:  92%|█████████▏| 1287/1400 [08:49<00:48,  2.34it/s]
# Baseline Epoch 1:  92%|█████████▏| 1288/1400 [08:49<00:46,  2.39it/s]
# Baseline Epoch 1:  92%|█████████▏| 1289/1400 [08:50<00:44,  2.47it/s]
# Baseline Epoch 1:  92%|█████████▏| 1290/1400 [08:50<00:45,  2.40it/s]
# Baseline Epoch 1:  92%|█████████▏| 1291/1400 [08:50<00:43,  2.53it/s]
# Baseline Epoch 1:  92%|█████████▏| 1292/1400 [08:51<00:48,  2.23it/s]
# Baseline Epoch 1:  92%|█████████▏| 1293/1400 [08:51<00:44,  2.38it/s]
# Baseline Epoch 1:  92%|█████████▏| 1294/1400 [08:52<00:43,  2.42it/s]
# Baseline Epoch 1:  92%|█████████▎| 1295/1400 [08:52<00:41,  2.52it/s]
# Baseline Epoch 1:  93%|█████████▎| 1296/1400 [08:52<00:39,  2.62it/s]
# Baseline Epoch 1:  93%|█████████▎| 1297/1400 [08:53<00:37,  2.73it/s]
# Baseline Epoch 1:  93%|█████████▎| 1298/1400 [08:53<00:37,  2.73it/s]
# Baseline Epoch 1:  93%|█████████▎| 1299/1400 [08:53<00:38,  2.66it/s]
# Baseline Epoch 1:  93%|█████████▎| 1300/1400 [08:54<00:38,  2.59it/s]
# Baseline Epoch 1:  93%|█████████▎| 1301/1400 [08:54<00:38,  2.60it/s]
# Baseline Epoch 1:  93%|█████████▎| 1302/1400 [08:55<00:37,  2.64it/s]
# Baseline Epoch 1:  93%|█████████▎| 1303/1400 [08:55<00:37,  2.61it/s]
# Baseline Epoch 1:  93%|█████████▎| 1304/1400 [08:56<00:40,  2.35it/s]
# Baseline Epoch 1:  93%|█████████▎| 1305/1400 [08:56<00:38,  2.48it/s]
# Baseline Epoch 1:  93%|█████████▎| 1306/1400 [08:56<00:36,  2.60it/s]
# Baseline Epoch 1:  93%|█████████▎| 1307/1400 [08:57<00:35,  2.60it/s]
# Baseline Epoch 1:  93%|█████████▎| 1308/1400 [08:57<00:38,  2.41it/s]
# Baseline Epoch 1:  94%|█████████▎| 1309/1400 [08:58<00:39,  2.31it/s]
# Baseline Epoch 1:  94%|█████████▎| 1310/1400 [08:58<00:36,  2.46it/s]
# Baseline Epoch 1:  94%|█████████▎| 1311/1400 [08:58<00:34,  2.56it/s]
# Baseline Epoch 1:  94%|█████████▎| 1312/1400 [08:59<00:35,  2.50it/s]
# Baseline Epoch 1:  94%|█████████▍| 1313/1400 [08:59<00:35,  2.46it/s]
# Baseline Epoch 1:  94%|█████████▍| 1314/1400 [08:59<00:33,  2.54it/s]
# Baseline Epoch 1:  94%|█████████▍| 1315/1400 [09:00<00:38,  2.20it/s]
# Baseline Epoch 1:  94%|█████████▍| 1316/1400 [09:00<00:34,  2.42it/s]
# Baseline Epoch 1:  94%|█████████▍| 1317/1400 [09:01<00:32,  2.59it/s]
# Baseline Epoch 1:  94%|█████████▍| 1318/1400 [09:01<00:29,  2.74it/s]
# Baseline Epoch 1:  94%|█████████▍| 1319/1400 [09:01<00:30,  2.66it/s]
# Baseline Epoch 1:  94%|█████████▍| 1320/1400 [09:02<00:30,  2.62it/s]
# Baseline Epoch 1:  94%|█████████▍| 1321/1400 [09:02<00:36,  2.17it/s]
# Baseline Epoch 1:  94%|█████████▍| 1322/1400 [09:03<00:36,  2.14it/s]
# Baseline Epoch 1:  94%|█████████▍| 1323/1400 [09:03<00:34,  2.25it/s]
# Baseline Epoch 1:  95%|█████████▍| 1324/1400 [09:04<00:30,  2.50it/s]
# Baseline Epoch 1:  95%|█████████▍| 1325/1400 [09:04<00:30,  2.49it/s]
# Baseline Epoch 1:  95%|█████████▍| 1326/1400 [09:04<00:29,  2.50it/s]
# Baseline Epoch 1:  95%|█████████▍| 1327/1400 [09:05<00:28,  2.54it/s]
# Baseline Epoch 1:  95%|█████████▍| 1328/1400 [09:05<00:29,  2.43it/s]
# Baseline Epoch 1:  95%|█████████▍| 1329/1400 [09:06<00:26,  2.64it/s]
# Baseline Epoch 1:  95%|█████████▌| 1330/1400 [09:06<00:27,  2.54it/s]
# Baseline Epoch 1:  95%|█████████▌| 1331/1400 [09:06<00:29,  2.35it/s]
# Baseline Epoch 1:  95%|█████████▌| 1332/1400 [09:07<00:27,  2.50it/s]
# Baseline Epoch 1:  95%|█████████▌| 1333/1400 [09:07<00:29,  2.27it/s]
# Baseline Epoch 1:  95%|█████████▌| 1334/1400 [09:08<00:29,  2.25it/s]
# Baseline Epoch 1:  95%|█████████▌| 1335/1400 [09:08<00:26,  2.47it/s]
# Baseline Epoch 1:  95%|█████████▌| 1336/1400 [09:09<00:25,  2.54it/s]
# Baseline Epoch 1:  96%|█████████▌| 1337/1400 [09:09<00:27,  2.29it/s]
# Baseline Epoch 1:  96%|█████████▌| 1338/1400 [09:09<00:26,  2.33it/s]
# Baseline Epoch 1:  96%|█████████▌| 1339/1400 [09:10<00:25,  2.36it/s]
# Baseline Epoch 1:  96%|█████████▌| 1340/1400 [09:10<00:24,  2.41it/s]
# Baseline Epoch 1:  96%|█████████▌| 1341/1400 [09:11<00:22,  2.57it/s]
# Baseline Epoch 1:  96%|█████████▌| 1342/1400 [09:11<00:23,  2.46it/s]
# Baseline Epoch 1:  96%|█████████▌| 1343/1400 [09:12<00:24,  2.37it/s]
# Baseline Epoch 1:  96%|█████████▌| 1344/1400 [09:12<00:24,  2.29it/s]
# Baseline Epoch 1:  96%|█████████▌| 1345/1400 [09:12<00:24,  2.24it/s]
# Baseline Epoch 1:  96%|█████████▌| 1346/1400 [09:13<00:23,  2.29it/s]
# Baseline Epoch 1:  96%|█████████▌| 1347/1400 [09:13<00:21,  2.47it/s]
# Baseline Epoch 1:  96%|█████████▋| 1348/1400 [09:14<00:20,  2.57it/s]
# Baseline Epoch 1:  96%|█████████▋| 1349/1400 [09:14<00:20,  2.49it/s]
# Baseline Epoch 1:  96%|█████████▋| 1350/1400 [09:14<00:19,  2.62it/s]
# Baseline Epoch 1:  96%|█████████▋| 1351/1400 [09:15<00:19,  2.49it/s]
# Baseline Epoch 1:  97%|█████████▋| 1352/1400 [09:15<00:19,  2.48it/s]
# Baseline Epoch 1:  97%|█████████▋| 1353/1400 [09:16<00:18,  2.55it/s]
# Baseline Epoch 1:  97%|█████████▋| 1354/1400 [09:16<00:16,  2.71it/s]
# Baseline Epoch 1:  97%|█████████▋| 1355/1400 [09:16<00:16,  2.76it/s]
# Baseline Epoch 1:  97%|█████████▋| 1356/1400 [09:17<00:16,  2.60it/s]
# Baseline Epoch 1:  97%|█████████▋| 1357/1400 [09:17<00:15,  2.71it/s]
# Baseline Epoch 1:  97%|█████████▋| 1358/1400 [09:17<00:16,  2.62it/s]
# Baseline Epoch 1:  97%|█████████▋| 1359/1400 [09:18<00:15,  2.59it/s]
# Baseline Epoch 1:  97%|█████████▋| 1360/1400 [09:18<00:14,  2.76it/s]
# Baseline Epoch 1:  97%|█████████▋| 1361/1400 [09:18<00:14,  2.75it/s]
# Baseline Epoch 1:  97%|█████████▋| 1362/1400 [09:19<00:13,  2.74it/s]
# Baseline Epoch 1:  97%|█████████▋| 1363/1400 [09:19<00:13,  2.70it/s]
# Baseline Epoch 1:  97%|█████████▋| 1364/1400 [09:20<00:13,  2.62it/s]
# Baseline Epoch 1:  98%|█████████▊| 1365/1400 [09:20<00:14,  2.49it/s]
# Baseline Epoch 1:  98%|█████████▊| 1366/1400 [09:20<00:13,  2.51it/s]
# Baseline Epoch 1:  98%|█████████▊| 1367/1400 [09:21<00:12,  2.62it/s]
# Baseline Epoch 1:  98%|█████████▊| 1368/1400 [09:21<00:12,  2.47it/s]
# Baseline Epoch 1:  98%|█████████▊| 1369/1400 [09:22<00:11,  2.61it/s]
# Baseline Epoch 1:  98%|█████████▊| 1370/1400 [09:22<00:12,  2.39it/s]
# Baseline Epoch 1:  98%|█████████▊| 1371/1400 [09:22<00:11,  2.47it/s]
# Baseline Epoch 1:  98%|█████████▊| 1372/1400 [09:23<00:10,  2.60it/s]
# Baseline Epoch 1:  98%|█████████▊| 1373/1400 [09:23<00:10,  2.47it/s]
# Baseline Epoch 1:  98%|█████████▊| 1374/1400 [09:24<00:10,  2.47it/s]
# Baseline Epoch 1:  98%|█████████▊| 1375/1400 [09:24<00:10,  2.44it/s]
# Baseline Epoch 1:  98%|█████████▊| 1376/1400 [09:24<00:09,  2.57it/s]
# Baseline Epoch 1:  98%|█████████▊| 1377/1400 [09:25<00:09,  2.53it/s]
# Baseline Epoch 1:  98%|█████████▊| 1378/1400 [09:25<00:08,  2.58it/s]
# Baseline Epoch 1:  98%|█████████▊| 1379/1400 [09:26<00:08,  2.41it/s]
# Baseline Epoch 1:  99%|█████████▊| 1380/1400 [09:26<00:08,  2.44it/s]
# Baseline Epoch 1:  99%|█████████▊| 1381/1400 [09:26<00:07,  2.44it/s]
# Baseline Epoch 1:  99%|█████████▊| 1382/1400 [09:27<00:07,  2.56it/s]
# Baseline Epoch 1:  99%|█████████▉| 1383/1400 [09:27<00:07,  2.41it/s]
# Baseline Epoch 1:  99%|█████████▉| 1384/1400 [09:28<00:06,  2.47it/s]
# Baseline Epoch 1:  99%|█████████▉| 1385/1400 [09:28<00:06,  2.27it/s]
# Baseline Epoch 1:  99%|█████████▉| 1386/1400 [09:29<00:06,  2.29it/s]
# Baseline Epoch 1:  99%|█████████▉| 1387/1400 [09:29<00:05,  2.23it/s]
# Baseline Epoch 1:  99%|█████████▉| 1388/1400 [09:30<00:05,  2.14it/s]
# Baseline Epoch 1:  99%|█████████▉| 1389/1400 [09:30<00:04,  2.31it/s]
# Baseline Epoch 1:  99%|█████████▉| 1390/1400 [09:30<00:04,  2.36it/s]
# Baseline Epoch 1:  99%|█████████▉| 1391/1400 [09:31<00:03,  2.45it/s]
# Baseline Epoch 1:  99%|█████████▉| 1392/1400 [09:31<00:03,  2.26it/s]
# Baseline Epoch 1: 100%|█████████▉| 1393/1400 [09:32<00:03,  2.31it/s]
# Baseline Epoch 1: 100%|█████████▉| 1394/1400 [09:32<00:02,  2.28it/s]
# Baseline Epoch 1: 100%|█████████▉| 1395/1400 [09:33<00:02,  2.36it/s]
# Baseline Epoch 1: 100%|█████████▉| 1396/1400 [09:33<00:01,  2.46it/s]
# Baseline Epoch 1: 100%|█████████▉| 1397/1400 [09:33<00:01,  2.59it/s]
# Baseline Epoch 1: 100%|█████████▉| 1398/1400 [09:34<00:00,  2.53it/s]
# Baseline Epoch 1: 100%|█████████▉| 1399/1400 [09:34<00:00,  2.39it/s]
# Baseline Epoch 1: 100%|██████████| 1400/1400 [09:35<00:00,  2.43it/s]
# Baseline Epoch 1 done. Last batch loss: 0.0000
# Baseline Epoch 2: 100%|██████████| 1400/1400 [09:30<00:00,  2.45it/s]
# Baseline Epoch 2 done. Last batch loss: 0.0000
# Baseline Epoch 3: 100%|██████████| 1400/1400 [09:30<00:00,  2.45it/s]
# Baseline Epoch 3 done. Last batch loss: 0.0012
#
# 🕰️ Training Temporal DPR...
# Temporal Epoch 1: 100%|██████████| 1400/1400 [09:32<00:00,  2.45it/s]
# Temporal Epoch 1 done. Last batch loss: 0.1019
# Temporal Epoch 2: 100%|██████████| 1400/1400 [09:35<00:00,  2.43it/s]
# Temporal Epoch 2 done. Last batch loss: 0.0000
# Temporal Epoch 3: 100%|██████████| 1400/1400 [09:33<00:00,  2.44it/s]
# Temporal Epoch 3 done. Last batch loss: 0.0022
# Temporal Epoch 4: 100%|██████████| 1400/1400 [09:33<00:00,  2.44it/s]
# Temporal Epoch 4 done. Last batch loss: 0.0015
# Temporal Epoch 5: 100%|██████████| 1400/1400 [09:34<00:00,  2.44it/s]
# Temporal Epoch 5 done. Last batch loss: 0.0074
# Temporal Epoch 6: 100%|██████████| 1400/1400 [09:34<00:00,  2.44it/s]
# Temporal Epoch 6 done. Last batch loss: 0.0000
#
# 📊 Global Evaluation Results on the Test Set:
# Embedding all batches: 100%|██████████| 350/350 [01:43<00:00,  3.39it/s]
# Baseline DPR: Top-1: 0.700 | Top-5: 0.995
# Embedding all batches: 100%|██████████| 350/350 [01:43<00:00,  3.37it/s]
# Temporal DPR: Top-1: 0.600 | Top-5: 0.954

# %%
def compute_recall(q_embs, c_embs, k):
    scores = torch.matmul(q_embs, c_embs.T)
    topk = scores.topk(k, dim=1).indices
    correct = torch.arange(scores.size(0)).to(scores.device)
    recall = (topk == correct.unsqueeze(1)).any(dim=1).float().mean()
    return recall.item()

print("\n📊 Global Evaluation Results on the Test Set (Recall):")

# Assuming all_q_embs and all_c_embs from the last evaluation run are still in memory.
# If not, you would need to re-run the evaluate_global function to get them.
# For this example, we will assume they are available.

# Calculate Recall@5 and Recall@10 for Baseline DPR
baseline_recall5 = compute_recall(all_q_embs, all_c_embs, k=5)
baseline_recall10 = compute_recall(all_q_embs, all_c_embs, k=10)
print(f"Baseline DPR: Recall@5: {baseline_recall5:.3f} | Recall@10: {baseline_recall10:.3f}")

# Calculate Recall@5 and Recall@10 for Temporal DPR
# Note: You would need to re-run the temporal_model evaluation to get its specific embeddings if they are not available.
# Assuming temporal_model was the last one evaluated and its embeddings are in all_q_embs and all_c_embs.
# If not, you would need to modify the evaluate_global function to return embeddings for both models.
# For this example, we will assume the temporal model's embeddings are the ones currently in all_q_embs and all_c_embs.
temporal_recall5 = compute_recall(all_q_embs, all_c_embs, k=5)
temporal_recall10 = compute_recall(all_q_embs, all_c_embs, k=10)
print(f"Temporal DPR: Recall@5: {temporal_recall5:.3f} | Recall@10: {temporal_recall10:.3f}")
